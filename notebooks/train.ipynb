# %% [markdown]
# # Models for learning word embeddings

# %%
import re
from collections import defaultdict  # For word frequency
from time import time  # To time our operations

import pandas as pd  # For data handling

load_model = '' # model_name
corpus = 'wiki'
#corpus = 'speeches'
model_name = 'fasttext'
#model = 'word2vec'
preprocessing_type = 'nltk'
#preprocessing = 'spacy'

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /home/jonatan/school/nlp-project/notebooks

# %%
if corpus == 'speeches':
    df = pd.read_csv("../output/speeches-1.csv", delimiter="|", lineterminator="\n")
    df = df.dropna().reset_index(drop=True)
    df.head()
elif corpus == 'wiki':
    data = open("../output/wikipedia2008_fi_lemmatized.txt").read()

# %% [markdown]
# ## Cleaning:

# %%
if corpus == 'speeches':
    if preprocessing_type == 'spacy':
        from preprocessing import spacy_preprocess
        df_clean = spacy_preprocess(df)
    elif preprocessing_type == 'nltk':
        from preprocessing import nltk_preprocess
        df_clean = nltk_preprocess(df)
    else:
        raise Exception("Non allowed parameter for preprocessing")
    print(f"Cleaned shape: {df_clean.shape}")

# %% [markdown]
# ## Bigrams:

# %%
from gensim.models.phrases import Phrases, Phraser

# %% [markdown]
# As `Phrases()` takes a list of list of words as input:

# %%
if corpus == 'speeches':
    speeches = [re.split(r"[.!?]", row) for row in df_clean['clean']]
    sentences = [sent.strip().split() for speech in speeches for sent in speech if sent != ""]
elif corpus == 'wiki':
    sentences = re.split(r"[.!?]", data) 
    sentences = [sent.strip().split() for sent in sentences if sent != ""]

# %%
sentences
# Out:
# [['redundanssi', 'olla', 'yli|määrä', ',', 'erityisesti', 'tieto', 'liittyä'],
#  ['myös',
#   'systeemi',
#   'voida',
#   'olla',
#   'redundanssi',
#   ',',
#   'yli|määrä',
#   'esimerkiksi',
#   'vara|osa',
#   'tai',
#   'vaihto|ehtoisa',
#   'toiminta|tapa',
#   'tai',
#   'rinnakkainen',
#   'järjestelmä'],
#  ['sotilaallisesti', 'reservi', 'olla', 'redundanssi'],
#  ['redundanssi',
#   'maksaa',
#   ',',
#   'mutta',
#   'varmistaa',
#   'systeemi',
#   'toiminta',
#   'esimerkiksi',
#   'kestää',
#   'virhe',
#   'tai',
#   'osa|systeemi',
#   'tuhoutua'],
#  ['jos',
#   'tieto',
#   'olla',
#   'redundanssi',
#   ',',
#   'tieto',
#   'voida',
#   'poistaa',
#   'osa',
#   ',',
#   'ja',
#   'tieto|sisältö',
#   'säilyä',
#   'silti',
#   'ennallaan'],
#  ['vastaavasti',
#   'järjestelmä',
#   'toimia',
#   ',',
#   'vaikka',
#   'kaikki',
#   'muu',
#   'paitsi',
#   'yksi',
#   'rinnakkainen',
#   'järjestelmä',
#   'ei',
#   'toimia'],
#  ['redundanssi',
#   'voida',
#   'myös',
#   'tarkoituksellisesti',
#   'lisätä',
#   'viesti',
#   'tai',
#   'järjestelmä'],
#  ['tekninen',
#   'tapa',
#   'lisätä',
#   'redundanssi',
#   'viesti',
#   'virhe',
#   'korjata',
#   'olla',
#   'virhe|korjaus|koodi'],
#  ['kun',
#   'tieto',
#   ',',
#   'esimerkiksi',
#   'puhe',
#   'olla',
#   'redundanssi',
#   ',',
#   'se',
#   'kestää',
#   'virhe'],
#  ['esimerkiksi',
#   'puhe',
#   'koodata',
#   'PCM-',
#   'järjestelmä',
#   '8000',
#   'näyte',
#   'sekunti',
#   ',',
#   'joki',
#   'yksi',
#   'näyte',
#   'olla',
#   '8',
#   'bitti',
#   ',',
#   '256',
#   'voimakkuus|taso',
#   'tai',
#   'vaihto|ehto'],
#  ['lause',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"',
#   'kestää',
#   'tuo',
#   '1',
#   ',',
#   '5',
#   'sekunti',
#   'ja',
#   'se',
#   'informaatio|sisältö',
#   'PCM-',
#   'koodata',
#   'olla',
#   '(',
#   '1',
#   ',',
#   '5',
#   '8000',
#   '*',
#   '8',
#   '=',
#   ')',
#   '96'],
#  ['000', 'bitti'],
#  ['vastaavasti', 'ASCII-koodilla', 'em'],
#  ['lause',
#   'koodautuu',
#   'kirjallinen',
#   '(',
#   '15',
#   'merkki',
#   '*',
#   '8',
#   'bitti',
#   '=',
#   ')',
#   '120',
#   'bitti'],
#  ['puhe',
#   'olla',
#   'siis',
#   'pelkkä',
#   'sanallinen',
#   'tieto',
#   'kanna',
#   'paljon',
#   'redundanssi'],
#  ['tämä',
#   'redundanssi',
#   'näkyä',
#   'muu',
#   'muassa',
#   'se',
#   'kuka',
#   'puhua',
#   ',',
#   'puhuja',
#   'painotus',
#   ',',
#   'mielen|tila',
#   ',',
#   'puhe',
#   'voimakkuus',
#   'jne'],
#  ['voida',
#   'siis',
#   'sanoa',
#   ',',
#   'että',
#   'sanoa',
#   'lause',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"',
#   'lähes',
#   'kuka',
#   'tahansa',
#   ',',
#   'mikä',
#   'mielen|tila',
#   'tahansa',
#   ',',
#   'mikä',
#   'painotus',
#   'tahansa',
#   ',',
#   'kuinka',
#   'voimakkaasti',
#   'tai',
#   'heikosti',
#   'tahansa',
#   ',',
#   'lause',
#   'tieto|sisältö',
#   'pysyä',
#   'sama'],
#  ['kaikki', 'em'],
#  ['tapaus',
#   'tulla',
#   'selvä',
#   ',',
#   'että',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"'],
#  ['toisaalta',
#   '120',
#   'bitti',
#   'voida',
#   'koodata',
#   'tuo',
#   'miljardi',
#   'miljardi',
#   '*',
#   'miljardi',
#   '*',
#   'miljardi',
#   'vaihto|ehto',
#   '(',
#   '1036',
#   ')',
#   ',',
#   'esimerkiksi',
#   'lause'],
#  ['lause',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"',
#   'voida',
#   'siis',
#   'koodata',
#   'vielä',
#   'paljon',
#   'vähempi',
#   'bitti',
#   'kuin',
#   '120',
#   'sopia',
#   'joku',
#   'muu',
#   'koodi',
#   'kuin',
#   'ASCII',
#   'tai',
#   'PCM'],
#  ['vähä',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"',
#   'voida',
#   'koodata',
#   'yksi',
#   'bitti'],
#  ['esimerkiksi',
#   'Liisa',
#   '(',
#   'Pekka',
#   'vaimo',
#   ')',
#   'olla',
#   'sopia',
#   'Matti',
#   '(',
#   'Liisa',
#   'rakastaja',
#   ')',
#   'kanssa',
#   ',',
#   'että',
#   'kaksi',
#   'sanoma|lehti',
#   'veranta',
#   'pöytä',
#   '(',
#   'joka',
#   'näkyä',
#   'tie',
#   ')',
#   'tarkoittaa',
#   '"',
#   'Pekka',
#   'ei',
#   'olla',
#   'kotona',
#   ',',
#   'tulla',
#   'käydä',
#   '"'],
#  ['kaikki',
#   'muu',
#   'lehti|määrä',
#   'veranta',
#   'pöytä',
#   'tarkoitavat',
#   'siis',
#   '"',
#   'Pekka',
#   'olla',
#   'kotona',
#   '"'],
#  ['Hawkwind', 'olla', 'samanniminen', 'yhtye', 'esikoinen|albumi'],
#  ['se',
#   'tuottaa',
#   'Pretty',
#   'Things',
#   'yhtye',
#   'kita|risti',
#   'Dick',
#   'Taylor'],
#  ['albumi',
#   'nauhoittaa',
#   'livenä',
#   'yhtye',
#   'soittaa',
#   'tuo',
#   'tunti',
#   'aika',
#   'studio',
#   ',',
#   'joka',
#   'jälkeen',
#   'nauhoitus',
#   'leikata',
#   'kappa|lei'],
#  ['albumi', 'julkaista', 'remasteroida', '1990|luku', 'puoliväli'],
#  ['Hawkwindin',
#   'ensimmäinen',
#   'kokoonpano',
#   'syntyä',
#   'vuosi',
#   '1969',
#   'kun',
#   'Famous',
#   'Cure-bluesyhtyeessä',
#   'soittaa',
#   'kita|risti',
#   'Dave',
#   'Brock',
#   'ja',
#   'Mick',
#   'Slattery',
#   'tavata',
#   'basisti',
#   'John',
#   'A',
#   'Harrison',
#   'ja',
#   'huomata',
#   'yhteinen',
#   'kiinnostus',
#   'elektroninen',
#   'musiikki',
#   'kohtaan'],
#  ['17|vuotias',
#   'rumpali',
#   'Terry',
#   'Ollis',
#   'löytyä',
#   'lehti-ilmoitus',
#   'kautta',
#   'ja',
#   'Nik',
#   'Turner',
#   'ja',
#   'Dik',
#   'Mik',
#   'olla',
#   'Brockin',
#   'vanha',
#   'tuttu',
#   'Lontoo',
#   'Ladbroke',
#   'Groven',
#   'hippi|alue'],
#  ['aluksi',
#   'yhtye',
#   'nimi',
#   'olla',
#   'Group',
#   'X',
#   ',',
#   'se',
#   'jälkeen',
#   'Hawkwind',
#   'Zoo',
#   'ja',
#   'lopulta',
#   'Hawkwind'],
#  ['yhtye',
#   'manageri',
#   'tulla',
#   'underground|piiri',
#   'toimia',
#   'promoottori',
#   'Doug',
#   'Smith',
#   'ja',
#   'levytys|sopimus',
#   'saada',
#   'Liberty',
#   'Recordsilta',
#   '(',
#   'myöhemmin',
#   'United',
#   'Artists',
#   ')',
#   'joka',
#   'jakelija',
#   'toimia',
#   'emi'],
#  ['Mick',
#   'Slattery',
#   'lähteä',
#   'ennen',
#   'levytys',
#   'ja',
#   'tila',
#   'ottaa',
#   'nuori',
#   'Huw',
#   'Lloyd',
#   'Langton'],
#  ['Langton',
#   'ja',
#   'Harrison',
#   'erota',
#   'yhtye',
#   'pian',
#   'levy',
#   'julkaisu',
#   'jälkeen'],
#  ['toinen',
#   'kitaristia',
#   'ei',
#   'ottaa',
#   'tila',
#   'ja',
#   'basisti',
#   'tulla',
#   'ensin',
#   'Thomas',
#   'Crimble',
#   'joka',
#   'erottaa',
#   'pian',
#   'koska',
#   'olla',
#   '"',
#   'liian',
#   'tavallinen',
#   '"',
#   'ja',
#   'hän',
#   'tilalle',
#   'tulla',
#   'Dave',
#   'Anderson'],
#  ['Hawkwind',
#   'soittaa',
#   'vuosi',
#   '1970',
#   'Isle',
#   'Of',
#   'Wightin',
#   'festivaali',
#   ',',
#   'ei',
#   'kuitenkaan',
#   'varsinainen',
#   'lapa',
#   ',',
#   'vaan',
#   'alue',
#   'ulkopuolella',
#   'olla',
#   'ns'],
#  ['protesti|alue', 'vasta|lause', 'kallis', 'lippu|hinta'],
#  ['festivaali',
#   'pää|esiintyjä',
#   'kuulua',
#   'Jimi',
#   'Hendrix',
#   'tulla',
#   'katsoa',
#   'yhtye',
#   'esitys',
#   ',',
#   'mutta',
#   'olla',
#   'liian',
#   'väsyä',
#   'jammailla',
#   'yhtye',
#   'kanssa'],
#  ['Hendrix',
#   'kuitenkin',
#   'omistaa',
#   'keikka',
#   'yksi',
#   'kappale|taka',
#   '"',
#   'hopea|naamainen',
#   'tyyppi',
#   '"',
#   'eli',
#   'Nik',
#   'Turnerille',
#   ',',
#   'joka',
#   'kasvo',
#   'olla',
#   'värjätä',
#   'hopea|maali'],
#  ['kappale', 'Hurry', 'olla', 'Sundown', '-', '4:50', 'The', 're|aso', 'Is'],
#  ['-',
#   '3:30',
#   'Be',
#   'Yourself',
#   '-',
#   '8:09',
#   'paranoia',
#   '(',
#   'Part',
#   'I',
#   ')',
#   '-',
#   '1:04',
#   'paranoia',
#   '(',
#   'Part',
#   'Ii',
#   ')',
#   '-',
#   '4:11',
#   'Seeing',
#   'It',
#   'As',
#   'You',
#   'Really',
#   'Are',
#   '-',
#   '10:43',
#   'Mirror',
#   'Of',
#   'Illusion',
#   '-',
#   '7:08',
#   'kaikki',
#   'kappale',
#   ':',
#   'Brock',
#   '/',
#   'Hawkwind',
#   'remasteroida',
#   'versio',
#   'bonus|kappale',
#   ':',
#   'Bring',
#   'It',
#   'olla',
#   'home',
#   '(',
#   'Willie',
#   'Dixon',
#   ')',
#   '-',
#   '3:18',
#   'Hurry',
#   'olla',
#   'Sundown',
#   '(',
#   'Brock',
#   '/',
#   'Hawkwind',
#   ')',
#   '-',
#   '5:06',
#   'Kiss',
#   'Of',
#   'The',
#   'Velvet',
#   'Whip',
#   '(',
#   'aka'],
#  ['Sweet',
#   'Mistress',
#   'Of',
#   'pai',
#   ')',
#   '(',
#   'Brock',
#   '/',
#   'Hawkwind',
#   ')',
#   '-',
#   '5:28',
#   'Cymbaline',
#   '(',
#   'Roger',
#   'Waters',
#   ')',
#   '-',
#   '4:04',
#   'muusikko',
#   ':',
#   'Dave',
#   'Brock',
#   ':',
#   'kitara',
#   ',',
#   'kosketin|soitin',
#   ',',
#   'laulu',
#   'Nik',
#   'Turner',
#   ':',
#   'saksofoni',
#   ',',
#   'huilu',
#   ',',
#   'laulu',
#   'Huw',
#   'Lloyd',
#   'Langton',
#   ':',
#   'kitara',
#   ',',
#   'laulu',
#   'John',
#   'A',
#   'Harrison',
#   ':',
#   'basso',
#   ',',
#   'laulu',
#   'Dik',
#   'Mik:',
#   'audio|generaattori',
#   'Terry',
#   'Ollis',
#   ':',
#   'rumpu',
#   'Mick',
#   'Slattery',
#   ':',
#   'kitara',
#   '(',
#   'bonus|kappale',
#   ')',
#   'kummitus',
#   ',',
#   'aave',
#   'tai',
#   'haamu',
#   'olla',
#   'uskomus',
#   'kuolla',
#   'ihminen',
#   'tai',
#   'eläin',
#   'sielu',
#   ',',
#   'joka',
#   'kulkea',
#   'elävä',
#   'maa|ilma',
#   ',',
#   'usein',
#   'sama',
#   'paikko',
#   'kuin',
#   'elää'],
#  ['tämä', 'elävä', 'maa|ilma', 'jäädä', 'kutsua', 'kummittelu'],
#  ['kummitella',
#   'sielu',
#   'väittää',
#   'usein',
#   'yrittää',
#   'saattaa',
#   'loppu',
#   'jokin',
#   'tehtävä',
#   ',',
#   'joka',
#   'jäädä',
#   'elämä',
#   'tehdä',
#   ',',
#   'tai',
#   'kärsiä',
#   'rangaistus',
#   'paha',
#   'teko'],
#  ['kummitus',
#   'katsoa',
#   'usein',
#   'olla',
#   'jonkinlainen',
#   'väli|tila',
#   ',',
#   'kuollut',
#   ',',
#   'mutta',
#   'kykenemätön',
#   'siirtyä',
#   'esimerkiksi',
#   'helvetti',
#   'tai',
#   'taivas'],
#  ['kummitus|tarina', 'löytyä', 'ympäri', 'maa|ilma'],
#  ['piirre',
#   'kummittelu',
#   'katsoa',
#   'liittyä',
#   'lähes',
#   'aina',
#   'jokin',
#   'paikka',
#   ',',
#   'joka',
#   'kummitus',
#   'olla',
#   'olla',
#   'elää'],
#  ['joskus',
#   'harvemmin',
#   'kummitus',
#   'myös',
#   'väittää',
#   'seuraava',
#   'elo',
#   'olla',
#   'suku|lainen'],
#  ['haamu',
#   'kuvata',
#   'usein',
#   'läpi|näkyvä',
#   ',',
#   'varjo|mainen',
#   ',',
#   'sumu|mainen',
#   'tai',
#   'luu|ranka'],
#  ['haamu',
#   'voida',
#   'myös',
#   'välillä',
#   'näky',
#   'kuten',
#   'elävä',
#   'ihminen',
#   ',',
#   'mutta',
#   'kadota',
#   'sitten',
#   'oudosti'],
#  ['yleensä',
#   'ajatella',
#   ',',
#   'että',
#   'haamu',
#   'voida',
#   'kulkea',
#   'aine',
#   'läpi',
#   ',',
#   'ei',
#   'se',
#   'voida',
#   'koskettaa',
#   ',',
#   'mutta',
#   'että',
#   'se',
#   'voida',
#   'koskettaa',
#   'ihminen',
#   'tai',
#   'siirrellä',
#   'esine'],
#  ['väittää',
#   ',',
#   'että',
#   'haamu',
#   'läpi',
#   'kulkea',
#   'saattaa',
#   'tuntua',
#   'erittäin',
#   'kylmä'],
#  ['kummitus|talo',
#   'kertoa',
#   'usein',
#   'olla',
#   'poikkeuksellinen',
#   'kylmä',
#   'kohta',
#   ',',
#   'joka',
#   'liikkua',
#   ',',
#   'vaikka',
#   'itse',
#   'olento',
#   'ei',
#   'näky|ikä'],
#  ['joku', 'ajatella', 'haamu', 'olla', 'ektoplasma'],
#  ['se',
#   'lisäksi',
#   'että',
#   'ihminen',
#   'kummitella',
#   ',',
#   'kertoa',
#   'eläin',
#   'ja',
#   'jopa',
#   'esine',
#   'ja',
#   'asia',
#   'kummitella'],
#  ['olla',
#   'esimerkiksi',
#   'varsin',
#   'paljon',
#   'tarina',
#   'kummitus|talo',
#   'ja',
#   'laiva',
#   'miehistö'],
#  ['kummitus|talo',
#   'sanoa',
#   'sekä',
#   'rakennus',
#   ',',
#   'joka',
#   'olla',
#   'kummitus',
#   'että',
#   'rakennus',
#   ',',
#   'joka',
#   'itse',
#   'kummitella'],
#  ['tarina',
#   'mukaan',
#   'eräs',
#   'linna',
#   'purkaa',
#   'lattia',
#   'sanoa',
#   'joskus',
#   'näkyä',
#   'katon|raja',
#   ',',
#   'joka',
#   'se',
#   'ennen',
#   'olla',
#   'sijaita'],
#  ['kuuluisa',
#   'esi|merkki',
#   'kummitus|laiva',
#   'olla',
#   'lentävä',
#   'hollanti|lainen'],
#  ['kummitus', 'kohdistua', 'se', 'uskoa', 'kansa', 'ja', 'yksilö', 'pelko'],
#  ['olla',
#   'myös',
#   'tarina',
#   'kummitus',
#   ',',
#   'joka',
#   'olla',
#   'varoittaa',
#   'ihminen',
#   'tai',
#   'pelastaa',
#   'ihminen',
#   ',',
#   'ja',
#   'joka',
#   'ei',
#   'vahingoittaa',
#   'ihminen'],
#  ['moni', 'aave', 'liittyä', 'kauhu|elo|kuva', 'olla', 'tehdä'],
#  ['nyky|aika',
#   'kummitus|usko',
#   'uskoa',
#   'kummitus',
#   'olemassaolo',
#   'ei',
#   'olla',
#   'kadota',
#   'kehittynyt',
#   'länsi|maa',
#   'todeta',
#   'vuosi',
#   '2007',
#   'julkaistussa',
#   'tanskalainen',
#   'tutkimus'],
#  ['tuo',
#   'joka',
#   'neljäs',
#   'vastaaja',
#   'uskoa',
#   'kummitus',
#   'ja',
#   'kokemus',
#   'kummitus',
#   'olla',
#   'tuo',
#   '15',
#   'prosentti',
#   'ihminen'],
#  ['henki|olento', 'kertoa', 'nähdä', 'moni', 'suomalainen'],
#  ['asia',
#   'olla',
#   'tutkia',
#   'moni',
#   'akateeminen',
#   'opin|näyte|työ',
#   ',',
#   'joskaan',
#   'ei',
#   'yhtä',
#   'laajasti',
#   'kuin',
#   'Tanska'],
#  ['moni',
#   'suomalainen',
#   'olla',
#   'kertoa',
#   'tavata',
#   'kuolla',
#   'omainen',
#   'henki|olento'],
#  ['muinainen',
#   'vainaja|usko',
#   'tuntua',
#   'elävä',
#   ',',
#   'mutta',
#   'eri|niminen',
#   'haltija',
#   'olla',
#   'unohtua'],
#  ['vielä',
#   '1960-',
#   'ja',
#   '1970|luku',
#   'vanhempi',
#   'ihminen',
#   'keskuudessa',
#   'uskoa',
#   'metsä',
#   'ja',
#   'muu',
#   'henki',
#   ',',
#   'joka',
#   'olla',
#   'oma',
#   'nimi'],
#  ['haltija|usko',
#   'hiipua',
#   'sama',
#   'aika',
#   'kun',
#   'tele|visio',
#   'alkaa',
#   'yleistyä'],
#  ['vainaja|henki',
#   'tai',
#   'muu',
#   'henki|olento',
#   'nähdä',
#   'olla',
#   'kyse',
#   'yksilöllinen',
#   'kokemus',
#   ',',
#   'joka',
#   'pyrkiä',
#   'selittää',
#   'eri',
#   'tapa'],
#  ['uskonto|tiede',
#   'näkö|kulma',
#   'kummitus|kokemus',
#   'olla',
#   'uskonnollinen',
#   'kokemus',
#   '–',
#   'vaikka',
#   'kirkko',
#   'ei',
#   'se',
#   'sellainen',
#   'hyväksyä'],
#  ['kun',
#   'ihminen',
#   'olla',
#   'kokemus',
#   ',',
#   'joka',
#   'ei',
#   'pystyä',
#   'selittää',
#   'uskonnollinen',
#   'järjestelmä',
#   'mukaan',
#   'hän',
#   'selittää',
#   'kokemus',
#   'kansan|omainen',
#   'uskomus',
#   'kautta'],
#  ['nyky|aika',
#   'henki|usko',
#   'olla',
#   'voida',
#   'viritä',
#   'myös',
#   'new',
#   'age',
#   'suuntaus',
#   'tai',
#   'muu',
#   'uususkontojen',
#   'vaikutus'],
#  ['Venäjä',
#   'olla',
#   'tavallinen',
#   ',',
#   'että',
#   'korkeasti',
#   'kouluttaa',
#   'ihminen',
#   'saattaa',
#   'uskoa',
#   'kummitus',
#   'ja',
#   'muu',
#   'henki|olento',
#   'viite',
#   'Seattle',
#   'Storm',
#   'olla',
#   'yhdysvaltalainen',
#   'nainen|kori|pallo|seura',
#   ',',
#   'joka',
#   'pelata',
#   "Women's",
#   'National',
#   'Basketball',
#   'Association',
#   'liiga'],
#  ['liiga',
#   'läntinen',
#   'konferenssi',
#   'kuulua',
#   'seura',
#   'pelata',
#   'ensimmäinen',
#   'kausi',
#   'WNBA:ssa',
#   'vuosi',
#   '2000'],
#  ['Storm',
#   'pelata',
#   'koti|ottelu',
#   'KeyArenalla',
#   'Seattle',
#   'Washington',
#   'osavaltio'],
#  ['historia',
#   'alku|vuosi',
#   'Seattle',
#   'Storm',
#   'aloittaa',
#   'taival',
#   'WNBA:ssa',
#   'vuosi',
#   '2000',
#   'laajennus|joukkue',
#   'yhdessä',
#   'Indiana',
#   'Feverin',
#   ',',
#   'Miami',
#   'sola',
#   'ja',
#   'Portland',
#   'Firen',
#   'kanssa'],
#  ['tämä',
#   'seura',
#   'Storm',
#   'ja',
#   'Fever',
#   'olla',
#   'ainoa',
#   'edelleen',
#   'toiminta',
#   'jatkaa'],
#  ['Stormin',
#   'ensimmäinen',
#   'kausi',
#   'olla',
#   'laajennus|joukkue',
#   'tyypillinen',
#   ',',
#   'se',
#   'hävitä',
#   'suuri',
#   'osa',
#   'ottelu',
#   ',',
#   '26',
#   '32',
#   ',',
#   'ja',
#   'jäädä',
#   'lopulta',
#   'konferenssi',
#   'ja',
#   'koko',
#   'liiga',
#   'hännille'],
#  ['joukkue',
#   'jäädä',
#   'läntinen',
#   'konferenssi',
#   'viimeinen',
#   'myös',
#   'seuraava',
#   'kausi',
#   'voitaa',
#   '10',
#   'ottelu',
#   'ja',
#   'hävitä',
#   '22'],
#  ['kausi',
#   '2002',
#   'Stormin',
#   'suunta',
#   'kääntyä',
#   ',',
#   'kun',
#   'se',
#   'onnistua',
#   'päästä',
#   'ensimmäinen',
#   'kerta',
#   'WNBA:n',
#   'pudotus|peli',
#   'sijoittua',
#   'konferenssi',
#   'neljäs',
#   'voitto|prosentti',
#   '53',
#   ',',
#   '1',
#   '(',
#   '17',
#   'voitto',
#   'ja',
#   '15',
#   'tappio',
#   ')'],
#  ['pudotus|peli',
#   'ensimmäinen',
#   'kierros',
#   'vastaan',
#   'asettua',
#   'hallitseva',
#   'WNBA-mestari',
#   'Los',
#   'Angeles',
#   'Spar',
#   ',',
#   'joka',
#   'olla',
#   'vahva',
#   'suora',
#   'voitto',
#   '2–0'],
#  ['Spar', 'edetä', 'lopulta', 'toinen', 'peräkkäinen', 'mestaruus'],
#  ['vuosi',
#   '2003',
#   'Storm',
#   'saada',
#   'uusi',
#   'valmentaja',
#   'seurata',
#   'kolme',
#   'kausi',
#   'valmentaa',
#   ',',
#   'kausi',
#   '2002',
#   'jälkeen',
#   'erota',
#   'Lin',
#   'Dunnin',
#   'tilalle'],
#  ['uusi',
#   'pää|valmentaja',
#   'olla',
#   'entinen',
#   'tähti|pelaaja',
#   'Anne',
#   'Donovan',
#   ',',
#   'Basketball',
#   'Hall',
#   'of',
#   'Fameen',
#   'vuosi',
#   '1995',
#   'valita',
#   'kaksinkertainen',
#   'olympia|voittaja'],
#  ['Storm',
#   'voittaa',
#   '2003',
#   'jälleen',
#   'yli',
#   'puoli',
#   'ottelu',
#   ',',
#   '18',
#   '34',
#   '(',
#   'voitto|prosentti',
#   '52',
#   ',',
#   '9',
#   ')',
#   ',',
#   'mutta',
#   'jäädä',
#   'pudotus|peli',
#   'ulkopuolelle',
#   'sijoittua',
#   'konferenssi',
#   'viides'],
#  ['hyvä',
#   'kausi',
#   'pelata',
#   'WNBA:n',
#   'varaus|tilaisuus',
#   'ykkönen|varaus',
#   'vuosi',
#   '2001',
#   ',',
#   'laita|hyökkääjä',
#   'ja',
#   'keskus|hyökkääjä',
#   'pelata',
#   'Lauren',
#   'Jackson',
#   'palkita',
#   'kausi',
#   'jälkeen',
#   'WNBA:n',
#   'arvokas',
#   'pelaaja'],
#  ['kausi',
#   '2004',
#   '–',
#   'WNBA-mestaruus',
#   'kausi',
#   '2004',
#   'olla',
#   'Stormin',
#   'historia',
#   'menestyksekäs'],
#  ['Storm',
#   'voittaa',
#   'runko|sarja',
#   '20',
#   'ottelu',
#   '34',
#   '(',
#   'voitto|prosentti',
#   '58',
#   ',',
#   '8',
#   ')',
#   'ja',
#   'sijoittua',
#   'runko|sarja',
#   'konferenssi',
#   'toinen'],
#  ['koko',
#   'liiga',
#   'vain',
#   'Los',
#   'Angeles',
#   'Spar',
#   'saavuttaa',
#   'hyvä',
#   'voitto|prosentti',
#   ',',
#   '73',
#   ',',
#   '5',
#   '(',
#   '25',
#   'voitto',
#   ',',
#   '9',
#   'tappi|ota',
#   ')'],
#  ['pudotus|peli',
#   'ensimmäinen',
#   'kierros',
#   'joukkue',
#   'saada',
#   'vasta|ansa',
#   'Minnesota',
#   'lynx',
#   ',',
#   'joka',
#   'kaatua',
#   'suoraan',
#   'kaksi',
#   'ottelu'],
#  ['konferenssi|finaali',
#   'vastaan',
#   'tulla',
#   'Sacramento',
#   'Monarchsin',
#   ',',
#   'joka',
#   'olla',
#   'yllättää',
#   'voittaa',
#   'ensimmäinen',
#   'kierros',
#   'Sparksin'],
#  ['Storm', 'olla', 'Monarchsia', 'hyvä', 'voitto', '2–1'],
#  ['loppu|ottelu',
#   'joukkue',
#   'pelata',
#   'itäinen',
#   'konferenssi',
#   'mestari',
#   'Connecticut',
#   'Sun',
#   'vastaan',
#   ',',
#   'joka',
#   'kaatua',
#   'tasainen',
#   'ottelu|sarja',
#   'voitto',
#   '2–1',
#   ',',
#   'piste',
#   '64',
#   '–68',
#   ',',
#   '67–65',
#   'ja',
#   '74',
#   '–60'],
#  ['Stormin',
#   'mestaruus',
#   'takuu|nainen',
#   'toimia',
#   'Lauren',
#   'Jackson',
#   'ja',
#   'taka|mies',
#   'peli|paikka',
#   'ja',
#   'laita|hyökkääjä',
#   'pelata',
#   'Betty',
#   'Lennox',
#   ',',
#   'joka',
#   'pussittaa',
#   'kolme',
#   'loppu|ottelu|sarja',
#   'ottelu',
#   'keski|määrin',
#   '22',
#   ',',
#   '3',
#   'piste',
#   'ottelu',
#   'kohden'],
#  ['Lennox',
#   'palkita',
#   'vuosi',
#   '2004',
#   'loppu|ottelu',
#   'arvokas',
#   'pelaaja',
#   'palkinto'],
#  ['Lennox',
#   'tulla',
#   'joukkue',
#   'ennen',
#   'kausi',
#   'alku',
#   'dispersal',
#   'draftin',
#   'kautta',
#   ',',
#   'kun',
#   'hän',
#   'entinen',
#   'seura',
#   'Cleveland',
#   'Rockers',
#   'lopettaa',
#   'toiminta'],
#  ['Jackson',
#   'ja',
#   'Lennoxin',
#   'ohella',
#   'Stormin',
#   'aloitus|viisikko',
#   'vuosi',
#   '2004',
#   'pudotus|peli',
#   'pelata',
#   'taka|mies',
#   'Sue',
#   'Bird',
#   ',',
#   'taka|mies',
#   '/',
#   'laita|hyökkääjä',
#   'Sheri',
#   'Sam',
#   'ja',
#   'laita|hyökkääjä',
#   '/',
#   'keskus|hyökkääjä',
#   'Kamila',
#   'Vodičková'],
#  ['kausi',
#   'jälkeen',
#   'Storm',
#   'joutua',
#   'luopua',
#   'Sam',
#   ',',
#   'joka',
#   'siirtyä',
#   'vapaa',
#   'agentti',
#   'Charlotte',
#   'Stingiin',
#   ',',
#   'ja',
#   'Vodičkovásta',
#   ',',
#   'joka',
#   'siirtyä',
#   'Phoenix',
#   'Mercuryyn'],
#  ['kausi',
#   '2005',
#   'eteenpäin',
#   'kausi',
#   '2005',
#   'Storm',
#   'menestyä',
#   'runko|sarja',
#   'yhtä',
#   'hyvin',
#   'kuin',
#   'edellinen',
#   ',',
#   'kun',
#   'se',
#   'sijoittua',
#   'konferenssi',
#   'toinen',
#   'voitto|prosentti',
#   '58',
#   ',',
#   '8',
#   '(',
#   '20',
#   'voitto',
#   'ja',
#   '14',
#   'tappio',
#   ')'],
#  ['pudotus|peli',
#   'seura',
#   'pudota',
#   'kuitenkin',
#   'jo',
#   'ensimmäinen',
#   'kierros',
#   'hävitä',
#   'voitto',
#   '1–2',
#   'Houston',
#   'Cometsille'],
#  ['Sam',
#   'ja',
#   'Vodičkován',
#   'Stormin',
#   'vakio|aloittaja',
#   'korvata',
#   'mestaruus|kausi',
#   'vaihto|pelaaja',
#   'rooli',
#   'pelata',
#   'Janell',
#   'Burse',
#   'vapaa',
#   'agentti',
#   'seura',
#   'tulla',
#   'Iziane',
#   'Castro',
#   'Marques',
#   'sama',
#   'viisi',
#   'pelaaja',
#   'pelata',
#   'vakituisesti',
#   'Stormin',
#   'avaus',
#   'myös',
#   'kausi',
#   '2006',
#   'ja',
#   '2007'],
#  ['joukkue',
#   'päästä',
#   'molemmat',
#   'pudotus|peli',
#   ',',
#   '2006',
#   'konferenssi',
#   'neljäs',
#   'seura',
#   'voitto|prosentti',
#   '52',
#   ',',
#   '9',
#   '(',
#   '18',
#   'voitto',
#   'ja',
#   '16',
#   'tappio',
#   ')',
#   'ja',
#   '2007',
#   'se',
#   'ikään',
#   'konferenssi',
#   'neljäs',
#   'voitto|prosentti',
#   'voitaa',
#   '17',
#   'runko|sarjaottelu',
#   'ja',
#   'hävitä',
#   'yhtä',
#   'moni'],
#  ['Stormin',
#   'pudotus|peli|taival',
#   'päättyä',
#   'molemmat',
#   'kausi',
#   'ensimmäinen',
#   'kierros',
#   ',',
#   '2006',
#   'se',
#   'hävitä',
#   'Los',
#   'Angeles',
#   'Sparksille',
#   'voitto',
#   '1–2',
#   'ja',
#   '2007',
#   'tuleva',
#   'mestari',
#   'Phoenix',
#   'Mercurylle',
#   'suoraan',
#   'kaksi',
#   'ottelu'],
#  ['Lauren',
#   'Jackson',
#   'valita',
#   'kausi',
#   '2007',
#   'jälkeen',
#   'toistamiseen',
#   'WNBA:n',
#   'arvokas',
#   'pelaaja'],
#  ['Storm', 'uudistua', 'kovasti', 'kausi', '2008'],
#  ['Anne',
#   'Donovan',
#   'jättää',
#   'pää|valmentaja',
#   'tehtävä',
#   'kausi',
#   '2007',
#   'jälkeen',
#   'ja',
#   'uusi',
#   'valmentaja',
#   'palkata',
#   'Brian',
#   'Agler'],
#  ['Storm',
#   'saada',
#   'myös',
#   'uusi',
#   'omistaja',
#   'vuosi',
#   '2008',
#   'alku',
#   ',',
#   'kun',
#   'Seattle',
#   'omistaja|ryhmä',
#   'Force',
#   '10',
#   'Hoops',
#   'ostaa',
#   'seura',
#   'NBA-seura',
#   'Seattle',
#   'SuperSonicsin',
#   'omistaja',
#   'Clayton',
#   'Bennettiltä',
#   'kymmenen',
#   'miljoona',
#   'dollari'],
#  ['joukkue',
#   'välttää',
#   'näin',
#   'SuperSonicksin',
#   'kohtalo',
#   ',',
#   'siirto',
#   'pois',
#   'Seattle'],
#  ['Bennett',
#   'olla',
#   'ostaa',
#   'SuperSonicksin',
#   'ja',
#   'Stormin',
#   'vuosi',
#   '2006'],
#  ['ennen',
#   'kausi',
#   '2008',
#   'Storm',
#   'hankkia',
#   'rivi',
#   'kolme',
#   'kokenut',
#   'tähti|pelaaja',
#   ',',
#   'aiemmin',
#   'kuusi',
#   'kausi',
#   'Detroit',
#   'Shockissa',
#   'pelata',
#   'Swin',
#   'Cashin',
#   ',',
#   'yhdeksän',
#   'kautta',
#   'Sacramento',
#   'Monarchsissa',
#   'pelata',
#   'keskus|hyökkääjä',
#   '/',
#   'laita|hyökkääjä',
#   'Yolanda',
#   'Griffithin',
#   'ja',
#   'vuosi',
#   '1997',
#   'Houston',
#   'Cometsia',
#   'edustaa',
#   'Sheryl',
#   'Swoopesin'],
#  ['edellinen|kausi',
#   'aloitus|viisikko',
#   'Janell',
#   'Burse',
#   ',',
#   'Iziane',
#   'Castro',
#   'Marques',
#   'ja',
#   'Betty',
#   'Lennox',
#   'saada',
#   'lähteä'],
#  ['pelaaja',
#   'Lauren',
#   'Jackson',
#   'olla',
#   'Stormin',
#   'historia',
#   'tehokas',
#   'pelaaja',
#   'hyökkäys|pää'],
#  ['hän',
#   'olla',
#   'olla',
#   'joukkue',
#   'paras',
#   'piste|nainen',
#   'ensimmäinen',
#   'WNBA-kaudestaan',
#   ',',
#   'kausi',
#   '2001',
#   'lähtien',
#   'joka',
#   'vuo',
#   'niin',
#   'piste|keski|arvo',
#   'mitata',
#   'kuin',
#   'kokonainen|piste|säkä'],
#  ['eniten',
#   'piste',
#   'hän',
#   'olla',
#   'tehdä',
#   'kausi',
#   '2007',
#   ',',
#   'joka',
#   'hän',
#   'tehdä',
#   'yhteensä',
#   '739',
#   'piste',
#   '31',
#   'runko|sarjaottelu',
#   ',',
#   'keski|määrin',
#   '23',
#   ',',
#   '8',
#   'ottelu',
#   'kohden'],
#  ['kausi',
#   '2000',
#   'joukkue',
#   'paras',
#   'piste|nainen',
#   'olla',
#   'Stormissa',
#   'vain',
#   'tuo',
#   'kausi',
#   'pelata',
#   'Edna',
#   'Campbell',
#   'Jackson',
#   'olla',
#   'olla',
#   'joka',
#   'kausi',
#   'Stormin',
#   'ykkönen|pelaaja',
#   'myös',
#   'levy|pallo',
#   'ja',
#   'blokki'],
#  ['eniten',
#   'levy|pallo',
#   'hän',
#   'olla',
#   'kerätä',
#   'kausi',
#   '2005',
#   ',',
#   'yhteensä',
#   '313',
#   '34',
#   'runko|sarjaottelu',
#   '(',
#   'keski|arvo',
#   'mitata',
#   'eniten',
#   'kausi',
#   '2007',
#   ',',
#   'yhteensä',
#   '300',
#   '31',
#   'ottelu',
#   ',',
#   'keski|määrin',
#   '9',
#   ',',
#   '7',
#   'per',
#   'ottelu',
#   ')'],
#  ['blokki',
#   'hän',
#   'olla',
#   'kerätä',
#   'eniten',
#   'kausi',
#   '2002',
#   ',',
#   'yhteensä',
#   '81',
#   '28',
#   'ottelu'],
#  ['kori',
#   'johtaa',
#   'syöttö',
#   'Stormin',
#   'ykkönen|pelaaja',
#   'olla',
#   'Sue',
#   'Bird',
#   ',',
#   'joka',
#   'tulla',
#   'joukkue',
#   'vuosi',
#   '2002',
#   'WNBA:n',
#   'varaus|tilaisuus',
#   'ykkönen|varaus'],
#  ['eniten',
#   'hän',
#   'olla',
#   'syöttää',
#   'kori',
#   'kausi',
#   '2003',
#   ',',
#   '221',
#   'kori',
#   '34',
#   'ottelu'],
#  ['pelaaja', 'nykyinen', 'pelaaja', 'tilanne', '18'],
#  ['heinä|kuu',
#   '2008',
#   ':',
#   'Sue',
#   'Bird',
#   '(',
#   'G',
#   ')',
#   'Swin',
#   'cash',
#   '(',
#   'F',
#   ')',
#   'Shyra',
#   'Ely',
#   '(',
#   'F',
#   ')',
#   'Katie',
#   'Gearlds',
#   '(',
#   'F-G',
#   ')',
#   'Yolanda',
#   'Griffith',
#   '(',
#   'C-F',
#   ')',
#   'Lauren',
#   'Jackson',
#   '(',
#   'F-C',
#   ')',
#   'Camille',
#   'Little',
#   '(',
#   'F',
#   ')',
#   'Kristen',
#   "O'Neill",
#   '(',
#   'G-F',
#   ')',
#   'Ashley',
#   'Robinson',
#   '(',
#   'C',
#   ')',
#   'Kelly',
#   'Santos',
#   '(',
#   'F',
#   ')',
#   'Sheryl',
#   'Swoopes',
#   '(',
#   'G',
#   ')',
#   'Tanisha',
#   'Wright',
#   '(',
#   'G',
#   ')',
#   'entinen',
#   'pelaaja',
#   'Adia',
#   'Barnes',
#   '(',
#   '2002–2004',
#   ')',
#   'Quacy',
#   'Barnes',
#   '(',
#   '2000–2001',
#   ')',
#   'Tully',
#   'Bevilaqua',
#   '(',
#   '2003–2004',
#   ')',
#   'Sandy',
#   'Brondello',
#   '(',
#   '2003',
#   ')',
#   'Janell',
#   'Burse',
#   '(',
#   '2004–2007',
#   ')',
#   'Edna',
#   'Campbell',
#   '(',
#   '2000',
#   ')',
#   'Iziane',
#   'Castro',
#   'Marques',
#   '(',
#   '2005–2007',
#   ')',
#   'Simone',
#   'Edwards',
#   '(',
#   '2000–2005',
#   ')',
#   'Sonja',
#   'Henning',
#   '(',
#   '2000–2002',
#   ')',
#   'Betty',
#   'Lennox',
#   '(',
#   '2004–2007',
#   ')',
#   'Semeka',
#   'Randall',
#   '(',
#   '2001–2002',
#   ')',
#   'Sheri',
#   'Sam',
#   '(',
#   '2004',
#   ')',
#   'Kamila',
#   'Vodičková',
#   '(',
#   '2000–2004',
#   ')',
#   'Henry',
#   'Hopkins',
#   'Sibley',
#   '(',
#   '25'],
#  ['touko|kuu', '1816', '–', '23'],
#  ['elo|kuu',
#   '1886',
#   ')',
#   'olla',
#   'prikaati|kenraali',
#   'Yhdysvalta',
#   'sisällis|sota'],
#  ['hän',
#   'taistella',
#   'konfederaation',
#   'armeija',
#   'uusi',
#   'Meksiko',
#   'territorio'],
#  ['lapsuus',
#   'ja',
#   'nuoruus',
#   'Sibleyn',
#   'perhe',
#   'emigroitua',
#   'Dorsetin',
#   'alue',
#   'Englanti'],
#  ['1629',
#   'hän',
#   'tulla',
#   'Amerikka',
#   'Winthropin',
#   'tutkimus|matka',
#   'mukana',
#   'ja',
#   'asettua',
#   'Massachusetts'],
#  ['Henry',
#   'isoisä',
#   'tohtori',
#   'John',
#   'Sibley',
#   'olla',
#   'palvella',
#   'lääkintä|mies',
#   'USA',
#   'vapaus|sota'],
#  ['ensimmäinen',
#   'vaimo',
#   'Elizabeth',
#   'Hopkinsin',
#   'kuolla',
#   'hän',
#   'muuttaa',
#   'Louisiana'],
#  ['tohtori',
#   'John',
#   'Sibley',
#   'asettua',
#   'Red',
#   'Riverin',
#   'rantama',
#   'Natchitochesiin'],
#  ['1803',
#   'hän',
#   'johtaa',
#   'tutkimus|retki',
#   'Länsi-Louisianaan',
#   'liitto|valtio',
#   'hallitus'],
#  ['1811',
#   'hän',
#   'poika',
#   'Samuel',
#   'Hopkins',
#   'Sibley',
#   'seurata',
#   'hän',
#   'Natchitochesiin',
#   ',',
#   'mikä',
#   'asua',
#   'kuolema',
#   'saakka',
#   '1823'],
#  ['kun',
#   'Henry',
#   'Hopkins',
#   'Sibley',
#   'olla',
#   'seitsemän',
#   'vanha',
#   'hän',
#   'lähettää',
#   'asua',
#   'setä',
#   'George',
#   'Champlin',
#   'Sibleyn',
#   'ja',
#   'hän',
#   'vaimo',
#   'Mary',
#   'Eastonin',
#   'kanssa'],
#  ['hän', 'perustaa', 'Lindenwoodin', 'college', 'St'],
#  ['Charles', 'Missouri'],
#  ['17|vuotias', 'Henry', 'mennä', 'sotilas|akatemia', 'West', 'Pointiin'],
#  ['hän',
#   'valmistua',
#   'USA',
#   'sotilas|akatemia',
#   '1838',
#   'ja',
#   'saada',
#   'komennus',
#   '2'],
#  ['luutnantti', '2'],
#  ['USA', 'rakuuna'],
#  ['hän',
#   'taistella',
#   'Seminole-intiaaneja',
#   'vastaan',
#   'Florida',
#   '1840-1841',
#   ';',
#   'osallistua',
#   'Texas',
#   'sotilaallinen',
#   'valloitus',
#   '1845-1846',
#   ';',
#   'ja',
#   'taistella',
#   'USA:n-Meksikon',
#   'sota',
#   '1847-1848'],
#  ['Sibley',
#   'olla',
#   'raja|seutu|palvelus',
#   'Teksas',
#   '1850-1855',
#   ',',
#   'ja',
#   'sitten',
#   'auttaa',
#   'hillitä',
#   'levottomuus',
#   'Kansas',
#   ',',
#   'joka',
#   'vuosi',
#   '1854',
#   'Kansas-Nebraska-sopimus',
#   'olla',
#   'aiheuttaa',
#   '1855-1857'],
#  ['Sibley',
#   'ottaa',
#   'osa',
#   'Utah',
#   'sota',
#   '1857-1860',
#   'ja',
#   'olla',
#   'aktiivi|palvelus',
#   'New',
#   'Mexico',
#   '1860-1861',
#   'kunnes',
#   'erota',
#   'sama',
#   'päivä',
#   'kun',
#   'hän',
#   'ylentää',
#   '1'],
#  ['rakuuna', 'majuri', '13'],
#  ['touko|kuu', '1861'],
#  ['1850|luku',
#   'hän',
#   'keksiä',
#   '"',
#   'Sibley-teltan',
#   '"',
#   ',',
#   'mikä',
#   'käyttää',
#   'laajalti',
#   'sisällis|sota',
#   'aika',
#   ',',
#   'ja',
#   'vähän',
#   'aika',
#   'se',
#   'jälkeen'],
#  ['hän',
#   'keksiä',
#   'myös',
#   '"',
#   'Sibley-kamiinan',
#   '"',
#   ',',
#   'joka',
#   'käyttää',
#   'toinen',
#   'maa|ilman|sota',
#   'alku',
#   'saakka'],
#  ['sisällis|sota',
#   'sisällis|sota',
#   'sytyttä',
#   'hän',
#   'liittyä',
#   'etelä|valtio',
#   'armeija'],
#  ['hän',
#   'epä|onnistunut',
#   'New',
#   'Mexico',
#   'kampanja',
#   'tähdätä',
#   'santa',
#   'Fe-Colorado',
#   'reitti',
#   'haltuunotto',
#   'ja',
#   'Kalifornia',
#   'lämmin',
#   'vesi|alue',
#   'vallata'],
#  ['hän',
#   'vastustaja',
#   'koko',
#   'kampanja',
#   'aika',
#   'olla',
#   'unioni',
#   'eversti',
#   'Edward',
#   'Canby',
#   ',',
#   'hän',
#   'entinen',
#   'ase|toveri',
#   'USA',
#   'armeija'],
#  ['hän',
#   'olla',
#   'pakko',
#   'perääntyä',
#   'Glorieta',
#   'passi',
#   'taistelu',
#   'jälkeen',
#   '(',
#   'kutsua',
#   'nimi',
#   '"',
#   'Gettysburg',
#   'länsi',
#   '"',
#   ')',
#   ',',
#   'mikä',
#   'hän',
#   'menettää',
#   'varuste|juna'],
#  ['sama',
#   'aika',
#   'hän',
#   'kohta',
#   'länsi',
#   'edetä',
#   'unioni',
#   'joukko',
#   ',',
#   'nimi',
#   'Kalifornia',
#   'karavaani'],
#  ['Sibleyn',
#   'perääntyä',
#   'san',
#   'Antonioon',
#   '1862',
#   'päättää',
#   'yritys',
#   'laajentaa',
#   'konfederaation',
#   'kansa|kunta',
#   'Tyynellemerelle',
#   ',',
#   'ja',
#   'hyödyntää',
#   'Kalifornia',
#   'mineraali|varanto'],
#  ['Sibleyn',
#   'myöhä',
#   'vaihe',
#   'New',
#   'Mexico',
#   'kampanja',
#   'epännistuttua',
#   'Sibley',
#   'saada',
#   'pieni',
#   'komennus',
#   'ja',
#   'kamppailla',
#   'alkoholismi',
#   'kanssa'],
#  ['1863', 'hän', 'joutua', 'sota|oikeus', 'Louisiana'],
#  ['vaikka',
#   'hän',
#   'ei',
#   'todeta',
#   'syyllinen',
#   'pelkuruuten',
#   'häntä',
#   'arvosteltiina',
#   'ankarasti'],
#  ['sota',
#   'jälkeen',
#   'hän',
#   'palvella',
#   'sotilas|neuvon|antaja',
#   'Egypti',
#   'ennen',
#   'kuin',
#   'palata',
#   'USA:aan',
#   'mikä',
#   'kuolla',
#   'köyhyys',
#   'Fredericksburgissa',
#   'Virginia'],
#  ['hän', 'olla', 'haudata', 'kaupunki', 'hautaus|maa'],
#  ['unioni',
#   'kenraali',
#   'ja',
#   'Minnesotan',
#   'kuvernööri',
#   'Henry',
#   'Hastings',
#   'Sibley',
#   'olla',
#   'hän',
#   'etäinen',
#   'suku|lainen'],
#  ['Sibley',
#   'mainita',
#   'usea',
#   'kerto',
#   'elo|kuva',
#   'hyvä',
#   ',',
#   'paha',
#   'ja',
#   'ruma'],
#  ['hän',
#   'nähdä',
#   'myös',
#   'vilaus',
#   'kohtaus',
#   ',',
#   'joka',
#   'henkilö|hahmo',
#   '"',
#   'Tuco',
#   '"',
#   'yrittää',
#   'yllättää',
#   '"',
#   'blondi',
#   '"',
#   'hotelli',
#   'Konfederaation',
#   'perääntyä',
#   'aiheuttaa',
#   'meteli',
#   'suoja'],
#  ['The',
#   'Transformers',
#   ':',
#   'The',
#   'Movie',
#   'olla',
#   'vuosi',
#   '1986',
#   'ilmestyä',
#   'Transformers-animaatioelokuva',
#   ',',
#   'joka',
#   'ohjata',
#   'nelson',
#   'Shin',
#   'ja',
#   'käsikirjoittaa',
#   'Ron',
#   'Friedman'],
#  ['elo|kuva',
#   'tapahtuma',
#   'sijoittua',
#   'alku|peräinen',
#   'tele|visio|sarja',
#   ',',
#   'The',
#   'Transformersin',
#   'jatkumo',
#   'ja',
#   'tapahtuma',
#   'sijoittua',
#   'toinen',
#   'ja',
#   'kolmas',
#   'tuotanto|kausi',
#   'välille',
#   ',',
#   'esitellä',
#   'uusi',
#   'hahmo',
#   'ja',
#   'maa|ilma'],
#  ['toisin',
#   'kuin',
#   'ensimmäinen',
#   'ja',
#   'toinen',
#   'tuotanto|kausi',
#   ',',
#   'elo|kuva',
#   'ei',
#   'sijoittua',
#   '1980|luku',
#   ',',
#   'vaan',
#   'tulevaisuus',
#   ',',
#   'vuosi',
#   '2005'],
#  ['The',
#   'Movie',
#   'erota',
#   'myös',
#   'animaatio|sarja',
#   'suuresti',
#   'se',
#   'synkkä',
#   'ja',
#   'aikuinen|mainen',
#   'toteutus'],
#  ['The',
#   'Transformers',
#   ':',
#   'The',
#   'Movie',
#   'jäädä',
#   'myös',
#   'Orson',
#   'Wellesin',
#   'ja',
#   'Scatman',
#   'Crothersin',
#   'viimeinen',
#   'elo|kuva|rooli'],
#  ['juoni',
#   'olla',
#   'vuo',
#   '2005',
#   'ja',
#   'Decepticonit',
#   'olla',
#   'vallata',
#   'Transformerien',
#   'koti|planeetta',
#   'Cybertronin'],
#  ['auto|botti',
#   'olla',
#   'perääntyä',
#   'Cybertronia',
#   'kiertää',
#   'kaksi',
#   'kuu',
#   ',',
#   'sekä',
#   'Maa',
#   'sijaita',
#   'tuki|kohta',
#   ',',
#   'Autobot',
#   'city'],
#  ['Megatron',
#   'Decepticoneineen',
#   'vallata',
#   'auto|botti',
#   'sukkula',
#   ',',
#   'tapattaa',
#   'se',
#   'miehistö',
#   'ja',
#   'aikoa',
#   'käyttää',
#   'sukkula',
#   'tehdä',
#   'yllätys|hyökkäys',
#   'Autobot',
#   'city',
#   ',',
#   'ja',
#   'tuhota',
#   'auto|botti'],
#  ['sama',
#   'aika',
#   'avaruus',
#   ',',
#   'planeetta',
#   'Cybertronia',
#   'lähestyä',
#   'valtava',
#   ',',
#   'planeetta',
#   'näköinen',
#   'hirviö',
#   ',',
#   'joka',
#   'syödä',
#   'kaikki',
#   'eteensätulevan'],
#  ['se', 'nimi', 'olla', 'Unicron', 'ja', 'kohde', 'tuhota', 'Cybertron'],
#  ['Optimus',
#   'Primen',
#   'kuolla',
#   'taistelu',
#   'Megatronia',
#   'vastaan',
#   ',',
#   'Starscream',
#   'kaappa',
#   'itse',
#   'Decepticonien',
#   'johtajuus',
#   'ja',
#   'auto|botti',
#   'uusi',
#   'johtaja',
#   'ultra',
#   'Magnus',
#   'komentaa',
#   'auto|botti',
#   'lähteä',
#   'kohti',
#   'koti|maa|ilma',
#   ',',
#   'tarkoitus',
#   'pelastaa',
#   'se',
#   ',',
#   'ennen',
#   'kuin',
#   'olla',
#   'liian',
#   'myöhäinen'],
#  ['Unicron',
#   'lähettää',
#   'kuitenkin',
#   'alaisuus',
#   'saada',
#   'Megatronin',
#   '(',
#   'uudeltan',
#   'nimi',
#   'Galvatron',
#   ')',
#   'auto|botti',
#   'perään',
#   ',',
#   'tarkoitus',
#   'tuhota',
#   'tämä',
#   'johtaja',
#   'olla',
#   'auto|botti',
#   'johtaja',
#   'tunnus',
#   ',',
#   'Matrix'],
#  ['tämä',
#   'ennen',
#   'Galvatron',
#   'eliminoida',
#   'Starscreamin',
#   'ja',
#   'kaapata',
#   'Decepticonien',
#   'johtajuus',
#   'takaisin',
#   'itse'],
#  ['Galvatroni',
#   'hyökätä',
#   'auto|botti',
#   'kimppuun',
#   'ja',
#   'tämä',
#   'vuoksi',
#   'auto|botti',
#   'joutua',
#   'erilleen',
#   'toinen',
#   ',',
#   'ympäri',
#   'avaruus',
#   ':',
#   'Hot',
#   'Rod',
#   ',',
#   'Kup',
#   'ja',
#   'Dinobotit',
#   'Quintessonien',
#   'planeetta',
#   'ja',
#   'ultra',
#   'Magnusen',
#   'joukko',
#   'romu|planeetta',
#   'Junkionille'],
#  ['Unicron', 'olla', 'jo', 'tuhota', 'molemmat', 'kuu|asema'],
#  ['enää', 'jäljellä', 'olla', 'vain', 'itse', 'pää|ruoka', ':', 'Cybertron'],
#  ['Transformers',
#   'Wheelien',
#   'apu',
#   'Hot',
#   'Rod',
#   'ja',
#   'Kup',
#   'pelastua',
#   'ja',
#   'saapua',
#   'sovitella',
#   'rauha',
#   'auto|botti',
#   'ja',
#   'Wreck-Garin',
#   'johtaa',
#   'Junkioiden',
#   'välille'],
#  ['Galvatron',
#   'olla',
#   'kuitenkin',
#   'kaapata',
#   'itse',
#   'auto|botti',
#   'Matrixin',
#   'ja',
#   'olla',
#   'palata',
#   'takaisin',
#   'Unicronin',
#   'luokse'],
#  ['Galvatron',
#   'aikoa',
#   'käyttää',
#   'Matrixia',
#   ',',
#   'tuhota',
#   'Unicronin',
#   ',',
#   'mutta',
#   'Matrix',
#   'ei',
#   'totella'],
#  ['Unicron',
#   'muuntautua',
#   'yllättää',
#   'valtava',
#   'jätti|robotti',
#   'ja',
#   'syödä',
#   'Galvatronin'],
#  ['Unicron',
#   'hyökätä',
#   'Cybertronin',
#   'kimppuun',
#   'ja',
#   'planeetta',
#   'hallita',
#   'Decepticonit',
#   'käydä',
#   'avuton',
#   'vasta|rinta',
#   'hirviö',
#   'vastaan'],
#  ['auto|botti',
#   'Hot',
#   'Rod',
#   ',',
#   'Kup',
#   ',',
#   'Springer',
#   ',',
#   'Archee',
#   'ja',
#   'ihminen|liittolainen',
#   'Daniel',
#   'joutua',
#   'alus',
#   'törmäys',
#   'sisälle',
#   'Unicroniin'],
#  ['erilleen',
#   'joutua',
#   'Hot',
#   'Rod',
#   'törmätä',
#   'Galvatroniin',
#   'ja',
#   'Galvatron',
#   'ehdottaa',
#   'liittoutua',
#   ',',
#   'mutta',
#   'Unicron',
#   'käyttää',
#   'tämä',
#   'henkinen',
#   'yhteys',
#   ',',
#   'pakottaa',
#   'Galvatronin',
#   'tuhota',
#   'auto|botti'],
#  ['Hot',
#   'Rod',
#   'ja',
#   'Galvatron',
#   'taistella',
#   'Unicronin',
#   'sisus',
#   ',',
#   'joka',
#   'johdosta',
#   'paljon',
#   'Galvatronia',
#   'heikko',
#   'Hot',
#   'Rod',
#   'hävitä'],
#  ['Galvatron',
#   'olla',
#   'juuri',
#   'kuristaa',
#   'Hot',
#   'Rodia',
#   ',',
#   'kun',
#   'Matrix',
#   ',',
#   'joka',
#   'roikkua',
#   'Galvatronin',
#   'kaula',
#   ',',
#   'reagoida'],
#  ['Matrix', 'tehdä', 'Hot', 'Rodista', 'uusi', '"', 'primen', '"'],
#  ['Hot',
#   'Rod',
#   'kasvaa',
#   'ja',
#   'vahvistua',
#   'uusi',
#   'Autobot',
#   'johtaja',
#   ',',
#   'Rodimus',
#   'Primeksi'],
#  ['Rodimus',
#   'Prime',
#   'heittää',
#   'Galvatronin',
#   'ulos',
#   'Unicronin',
#   'sisältä',
#   'ja',
#   'avata',
#   'Matrixin'],
#  ['valloilleen',
#   'päästä',
#   'tuho|voima',
#   'aiheuttaa',
#   'valtava',
#   'räjähdys',
#   'Unicronin',
#   'sisus'],
#  ['Rodimus',
#   'johdattaa',
#   'sisällä',
#   'olla',
#   'auto|botti',
#   'ulos',
#   'Unicronista'],
#  ['Unicron', 'räjähtää', ',', 'valtava', 'räjähdys'],
#  ['vain', 'Unicronin', 'pää', 'jäädä', 'jäljelle'],
#  ['se', 'alkaa', 'kiertää', 'Cybertronin', 'ympärillä'],
#  ['auto|botti',
#   'palata',
#   'uusi',
#   'johtaja',
#   'avustus',
#   'takaisin',
#   'Cybertronille',
#   'ja',
#   'Rodimus',
#   'Prime',
#   'todeta',
#   'tapahtua',
#   'olla',
#   'merkki',
#   'Cybertronin',
#   'sota',
#   'loppua',
#   'ja',
#   'se',
#   ',',
#   'että',
#   'kaikki',
#   'olla',
#   'jälleen',
#   'yhtä'],
#  ['ääni|näyttelijä',
#   'kritiikki',
#   'elokuvata',
#   'olla',
#   'kritisoida',
#   'moni',
#   'tärkeä',
#   'alku|peräinen|hahmo',
#   'tapattaa'],
#  ['tämä', 'siksi', ',', 'että', 'uusi', 'hahmo', 'saada', 'vanha', 'tilalle'],
#  ['Karl', 'Gerhard', ',', 'alku', 'perin', 'Karl', 'Johnson', ',', '(', 's'],
#  ['14'],
#  ['huhtikuu', '1891', ',', 'Tukholma', '–', 'k'],
#  ['22'],
#  ['huhtikuu',
#   '1964',
#   ',',
#   'Saltsjöbaden',
#   ')',
#   'olla',
#   'ruotsalainen',
#   'revyy|artisti',
#   ',',
#   'teatteri|ohjaaja',
#   ',',
#   'revyy',
#   'ja',
#   'kupletti|kirjoittaja'],
#  ['hän',
#   'olla',
#   'naimisissa',
#   'kolme',
#   'kerta',
#   ':',
#   '1913–1920',
#   'Mary',
#   'Johnsonin',
#   ',',
#   '1922–1929',
#   'Valborg',
#   'Geyronin',
#   'ja',
#   '1930–1969',
#   'Brita',
#   'Wernerin',
#   'kanssa'],
#  ['Gerhard',
#   'olla',
#   'per',
#   'Gerhardin',
#   'isä',
#   'ja',
#   'fatima',
#   'Ekmanin',
#   'adoptioisä'],
#  ['ura',
#   'aika',
#   'Gerhard',
#   'ehtiä',
#   'kirjoittaa',
#   'yli',
#   '4',
#   '000',
#   'kupletti',
#   'ja',
#   'yli',
#   '100',
#   'revyy'],
#  ['elämä',
#   'Karl',
#   'Gerhard',
#   'syntyä',
#   'Karl',
#   'Emil',
#   'Georg',
#   'Johnson',
#   'niminen'],
#  ['ensimmäinen',
#   'revyy',
#   'hän',
#   'allekirjoittaa',
#   '"',
#   'Hvem',
#   'är',
#   'Hvem',
#   '"',
#   'nimi',
#   ',',
#   'mutta',
#   'sitten',
#   'päättää',
#   'käyttää',
#   'itse',
#   'Karl',
#   'Gerhard',
#   'nimi'],
#  ['myöhemmin', 'hän', 'saada', 'lupa', 'vaihtaa', 'Gerhardin', 'suku|nimi'],
#  ['hän',
#   'syntyä',
#   'Tukholma',
#   'ja',
#   'olla',
#   'moni',
#   'vuosi',
#   'aika',
#   'näyttelijä',
#   'erilainen',
#   'matkustaa',
#   'teatteri|seura'],
#  ['vuosi', '1913', 'hän', 'avioitua', 'Mary', 'Johnsonin', 'kanssa'],
#  ['hän',
#   'nousta',
#   'suku|nimi',
#   'kanssa',
#   'tähti',
#   'Ruotsi',
#   'kukoistaa',
#   'elo|kuva|teollisuus'],
#  ['liitto', 'päättyä', 'avio|ero', ',', 'kuten', 'kaksi', 'tuleva', 'liitto'],
#  ['1930|luku',
#   'Gerhard',
#   'asua',
#   'yhdessä',
#   'koreografi',
#   'Karen',
#   'Scheuzin',
#   'kanssa'],
#  ['1950|luku',
#   'hän',
#   'asua',
#   'sihteeri',
#   'Göthe',
#   'Ericsson',
#   'ja',
#   'adoptio|lapsi',
#   'Fatiman',
#   'kanssa'],
#  ['Gerhard',
#   'debytoida',
#   'kupletti|laulaja',
#   'vuosi',
#   '1919',
#   'Fenix-kabareessa',
#   'Tukholma',
#   ',',
#   'jolloin',
#   'hän',
#   'esiintyä',
#   'Ernst',
#   'Rolf',
#   'seuraaja'],
#  ['Gerhard',
#   'kilpailla',
#   'Rolf',
#   'kanssa',
#   '1920|luku',
#   'kirjoittaja',
#   'ja',
#   'revyy|tuottaja'],
#  ['silloin',
#   'hän',
#   'saada',
#   'maine',
#   'Tukholma',
#   'ilkeä',
#   'ja',
#   'tyylikäs',
#   'revyy|kupletti',
#   'kirjoittaja'],
#  ['se',
#   'aika',
#   'tunnettu',
#   'kuulua',
#   '"',
#   'Jazzgossen',
#   '"',
#   ',',
#   '"',
#   'Lilla',
#   'Frida',
#   '"',
#   ',',
#   '"',
#   'Hurra',
#   'va',
#   'ja',
#   'ä',
#   'bra',
#   '"',
#   'ja',
#   '"',
#   'Hej',
#   'på',
#   'dej',
#   'du',
#   'gamla',
#   'primadonna',
#   '"'],
#  ['Rolf',
#   'kuolema',
#   'jälkeen',
#   'Gerhardin',
#   'revyy',
#   'tulla',
#   'kallis|arvoisa',
#   'ja',
#   'luksus|luonteinen',
#   ',',
#   'ja',
#   'hän',
#   'tulla',
#   'tunnettu',
#   'Tukholma',
#   'revyy|kuningas',
#   'ja',
#   'Ruotsi',
#   'Aristofanesina'],
#  ['usea',
#   'revyy',
#   ',',
#   'kuten',
#   'Oss',
#   'greker',
#   'emellan',
#   '(',
#   'Folkan-teatterissa',
#   '1933',
#   ')',
#   'ja',
#   'Köpmännen',
#   'i',
#   'Nordens',
#   'Venedig',
#   '(',
#   'Folkan-teatterissa',
#   '1936',
#   ')',
#   ',',
#   'olla',
#   'Zarah',
#   'Leander',
#   'primadonna'],
#  ['hän',
#   'tunnettu',
#   'kupletti',
#   'tuo',
#   'aika',
#   'olla',
#   '"',
#   'Nu',
#   'ska',
#   'vi',
#   'vara',
#   'snälla',
#   '"',
#   'ja',
#   '"',
#   'Ett',
#   'bedårande',
#   'barn',
#   'av',
#   'sin',
#   'tid',
#   '"'],
#  ['Zarahille',
#   'hän',
#   'kirjoittaa',
#   'laulu',
#   '"',
#   'I',
#   'skuggan',
#   'av',
#   'ei',
#   'stövel',
#   '"',
#   'vuosi',
#   '1934',
#   'vakava',
#   'protesti',
#   'Eurooppa',
#   'juutalais|vaino',
#   'kohtaan',
#   ',',
#   'mikä',
#   'ei',
#   'kuitenkaan',
#   'estää',
#   'Zarahia',
#   'muuttaa',
#   'Natsi-Saksaan',
#   'kolme',
#   'vuosi',
#   'myöhemmin'],
#  ['ensimmäinen',
#   'poliittinen',
#   'teos',
#   'Gerhard',
#   'tehdä',
#   'saksalainen',
#   'natsismi',
#   'ja',
#   'Ruotsi',
#   'myönnytys|politiikka',
#   'ruoskia'],
#  ['hän',
#   'itse',
#   'olla',
#   'paljon',
#   'positiivinen',
#   'asenne',
#   'neuvosto|liitto',
#   'kohtaan',
#   ',',
#   'ja',
#   'lainata',
#   'Moskova',
#   'matka',
#   'melodia',
#   'kupletti',
#   ',',
#   'joka',
#   'tulla',
#   'hän',
#   'natsi|vastainen',
#   'mestari|teos',
#   ',',
#   '"',
#   'Den',
#   'ökända',
#   'hästen',
#   'från',
#   'Troja',
#   '"'],
#  ['se', 'olla', 'laulaa', 'Gullregn-revyyllä', '1940'],
#  ['poliisi',
#   'kieltää',
#   'vanhentua',
#   'Tukholma',
#   'määräys|sääntö',
#   'lakipykälä',
#   'avustus',
#   'kupletti',
#   'laulaa',
#   ',',
#   'mikä',
#   'olla',
#   'tulla',
#   'tunnettu',
#   'esi|merkki',
#   'Ruotsi',
#   'huono',
#   'luonne',
#   'ja',
#   'itsesensuuri',
#   'sota',
#   'aika'],
#  ['Gerhardin',
#   'revyy',
#   'vetää',
#   'vähemmän',
#   'yleisö',
#   'vuosi',
#   '1940',
#   'jälkeen'],
#  ['Gerhardista',
#   'ei',
#   'koskaan',
#   'enää',
#   'tulla',
#   'poliittinen',
#   'taistelu|hahmo',
#   ',',
#   'mutta',
#   'eli',
#   'hyvin',
#   'hyvä',
#   'maine'],
#  ['1950|luku',
#   'hän',
#   'kirjoittaa',
#   'sarja',
#   'muistelma|kirja',
#   ',',
#   '(',
#   'om',
#   'jag',
#   'inte',
#   'minns',
#   'fel',
#   ',',
#   'Katt',
#   'bland',
#   'hermeliner',
#   ',',
#   'Lite',
#   'gullgren',
#   ')',
#   ',',
#   'kiertää',
#   'tehdä',
#   'esitys',
#   'yhdessä',
#   'Bo',
#   'Ekemarin',
#   'kanssa',
#   ',',
#   'olla',
#   'usein',
#   'mukana',
#   'radio',
#   'vanha',
#   'ja',
#   'uusi',
#   'kupletti',
#   ',',
#   'ja',
#   'kirjoittaa',
#   'joka',
#   'vuo',
#   'uusi|vuosi|revyy',
#   ',',
#   'joka',
#   'näytellä',
#   'ensimmäinen',
#   'kerta',
#   'Göteborgissa',
#   'ja',
#   'sitten',
#   'Tukholma'],
#  ['hän',
#   'tehdä',
#   'yhteis|työ',
#   'Povel',
#   'Ramelin',
#   'kanssa',
#   'ja',
#   'olla',
#   'mukana',
#   'muutama',
#   'Knäppupp-revyyssä',
#   'vuosi',
#   '1957–1960'],
#  ['hän',
#   'viimeinen',
#   'koko|ilta',
#   'revyy',
#   'olla',
#   'vuosi',
#   '1961',
#   'Ursäkta',
#   'handsken',
#   ',',
#   'joka',
#   'ohjata',
#   'Tage',
#   'Danielsson'],
#  ['vuosi',
#   '1952',
#   'Gerhard',
#   'johtaa',
#   'vasa|teatteri',
#   'yhdessä',
#   'poika',
#   'per',
#   'Gerhardin',
#   'kanssa',
#   ',',
#   'ja',
#   'saada',
#   'silla',
#   'tällöin',
#   'rooli',
#   'komedia'],
#  ['kuolema',
#   'ja',
#   'se',
#   'jälkeen',
#   'Gerhard',
#   'kuolla',
#   'näyttely|tauko',
#   'aika',
#   '22'],
#  ['huhtikuu', '1964', ',', 'kun', 'hän', 'tehdä', 'sydän|leikkaus'],
#  ['Gerhardin',
#   'viimeinen',
#   'rooli',
#   'jäädä',
#   'Peter',
#   'Ustinovin',
#   'Mitt',
#   'bedårande',
#   'jag',
#   '(',
#   'Photo',
#   'Finish',
#   ')',
#   'näytelmä'],
#  ['vaikka',
#   'Karl',
#   'Gerhardia',
#   'pidetä',
#   'legenda',
#   ',',
#   'Ruotsi',
#   'suuri',
#   'teatteri|persoona',
#   'ja',
#   'satiiri',
#   'tekijä',
#   ',',
#   'ei',
#   'kukaan',
#   'olla',
#   'ehtiä',
#   'nähdä',
#   'vaiva',
#   'kirjoittaa',
#   'tyhjentävä',
#   'elämä|kerta',
#   'hän'],
#  ['Gerhardista',
#   'olla',
#   'kuitenkin',
#   'jokin',
#   'kirja',
#   'tehdä',
#   ',',
#   'kuten',
#   'Stig',
#   'Ahlgrenin',
#   'Den',
#   'okände',
#   'Karl',
#   'Gerhard',
#   'vuosi',
#   '1966',
#   'ja',
#   'Åke',
#   'Pettersson',
#   'tohtorin|väitös|kirja',
#   'Oss',
#   'greker',
#   'emellan'],
#  ['ei', 'klassisk', 'komedi', 'i', 'revyform', 'vuosi', '1976'],
#  ['Pettersson', 'olla', 'Karl', 'Gerhard', 'seura', 'puheen|johtaja'],
#  ['ruotsalainen',
#   'muusikko',
#   'Magnus',
#   'Uggla',
#   'julkaista',
#   'vuosi',
#   '2006',
#   'levy',
#   ',',
#   'Ett',
#   'bedårande',
#   'barn',
#   'av',
#   'sin',
#   'tid',
#   ',',
#   'joka',
#   'hän',
#   'tulkita',
#   'Gerhardin',
#   'kupletti'],
#  ['albumi', 'kappale|isi', 'kuulua', 'muu', 'muassa', '”', 'Jazzgossen', '”'],
#  ['filmografia',
#   'näyttelijä',
#   '1913',
#   '–',
#   'Mannekängen',
#   '1917',
#   '–',
#   'I',
#   'mörkrets',
#   'bojor',
#   '1918',
#   '–',
#   'Mästerkatten',
#   'i',
#   'stövlar',
#   '1929',
#   '–',
#   'Säg',
#   'det',
#   'i',
#   'toner',
#   '1932',
#   '–',
#   'Lyckans',
#   'gullgossar',
#   '1935',
#   '–',
#   'Äktenskapsleken',
#   '1945',
#   '–',
#   'Skådetennis',
#   '1953',
#   '–',
#   'Vi',
#   'tre',
#   'debutera',
#   '1958',
#   '–',
#   'Jazzgossen',
#   'käsi|kirjoitus',
#   '1925',
#   '–',
#   'Hennes',
#   'lilla',
#   'Majestät',
#   '(',
#   '1925',
#   ')',
#   '1935',
#   '–',
#   'Äktenskapsleken',
#   '1939',
#   '–',
#   'Hennes',
#   'lilla',
#   'Majestät',
#   '(',
#   '1939',
#   ')',
#   'valikoida',
#   'bibliografia',
#   '1931',
#   '–',
#   'Åsså',
#   'kommer',
#   'det',
#   'ei',
#   'gosse',
#   '1945',
#   '–',
#   'I',
#   'skuggan',
#   'av',
#   'ei',
#   'stövel',
#   '(',
#   'poliittinen',
#   'revyy|teksti',
#   ')',
#   '1950',
#   '–',
#   'Karl',
#   'Gerhards',
#   'bästa',
#   '(',
#   'laulu',
#   'ja',
#   'nuotti',
#   ')',
#   '1952',
#   '–',
#   'om',
#   'jag',
#   'inte',
#   'minns',
#   'fel',
#   '1956',
#   '–',
#   'Katt',
#   'bland',
#   'hermeliner',
#   '1961',
#   '–',
#   'Lite',
#   'gullregn',
#   '1964',
#   '–',
#   'Med',
#   'mitt',
#   'goda',
#   'minne',
#   '1980|luku',
#   '–',
#   'Köpmännen',
#   'i',
#   'Nordens',
#   'Venedig',
#   '(',
#   'revyy|käsi|kirjoitus',
#   'vuosi',
#   '1936',
#   ',',
#   'Karl',
#   'Gerhard',
#   'seura',
#   'julkaista',
#   ')',
#   'kumi|saapas',
#   'olla',
#   'veden|pitävä',
#   'saapas',
#   ',',
#   'joka',
#   'yleinen',
#   'valmistaa',
#   'kumi|seos'],
#  ['niisi',
#   'käyttö',
#   'Britannia',
#   'aristokraatti',
#   'piiri',
#   'lisätä',
#   'muodikas',
#   'jalkine',
#   'Arthur',
#   'Wellesly',
#   ',',
#   'Wellingtonin',
#   'ensimmäinen',
#   'herttua',
#   '1800|luku',
#   'alku|puoli'],
#  ['nykyisin',
#   'halpa',
#   'kumi|saapas',
#   'valmistaa',
#   'myös',
#   'muu',
#   'muassa',
#   'PVC',
#   'muovi',
#   'ja',
#   'polyuretaani'],
#  ['se',
#   'olla',
#   'nykyään',
#   'lähes',
#   'aina',
#   'valmistaa',
#   'kumi',
#   'tai',
#   'synteettinen',
#   'vastine'],
#  ['se',
#   'yleensä',
#   'käyttää',
#   'märkä',
#   ',',
#   'sateinen',
#   'tai',
#   'mutainen',
#   'olo|suhde',
#   'suojata',
#   'käyttäjä',
#   'kosteus',
#   ',',
#   'joten',
#   'eri',
#   'versio',
#   'löytyä',
#   'kaikki',
#   'manner'],
#  ['niisi',
#   'pituus',
#   'vaihdella',
#   'mutta',
#   'olla',
#   'usein',
#   'lähes',
#   'polven|korkuinen'],
#  ['historia',
#   'Arthur',
#   'Wellesley',
#   ',',
#   'Wllingtonin',
#   'ensimmäinen',
#   'herttua',
#   'ohjata',
#   'kenkä|valmistaja',
#   ',',
#   'Hoby',
#   'of',
#   'St'],
#  ['James',
#   "'",
#   'Street',
#   ',',
#   'Lontoo',
#   'muokata',
#   '1700|luku',
#   '"',
#   'Hessian',
#   'boot',
#   '"',
#   'kenkä'],
#  ['tämä',
#   'loppu|tulos',
#   'olla',
#   'uusi',
#   'pehmeä|nahkainen',
#   'malli',
#   ',',
#   'joka',
#   'saumaus',
#   'olla',
#   'lähempänä',
#   'jalka'],
#  ['saapas',
#   'ulottua',
#   'puoli',
#   'sää|reki',
#   ';',
#   'niisi',
#   'korko',
#   'olla',
#   'matala',
#   '(',
#   'tuo',
#   'tuuma',
#   'korkuinen',
#   ')'],
#  ['malli',
#   'olla',
#   'tarpeeksi',
#   'vahva',
#   'taistelu|käyttö',
#   'mutta',
#   'samalla',
#   'mukavuus',
#   'myös',
#   'illallis|kutsu',
#   'sovia'],
#  ['"',
#   'rauta',
#   'herttua',
#   '"',
#   'ei',
#   'tietää',
#   'että',
#   'tulla',
#   'lopulta',
#   'malli',
#   'saada',
#   'paikka',
#   'saapas',
#   'englanti',
#   'kieli',
#   '(',
#   'Wellington',
#   'boot',
#   ',',
#   'herttua',
#   'voida',
#   'nähdä',
#   'saapas',
#   'kanssa',
#   'ohessa',
#   'olla',
#   'taulu',
#   'vuosi',
#   '1815',
#   ',',
#   'maa|lata',
#   'James',
#   'Lonsdale'],
#  [')',
#   'saapas',
#   'saada',
#   'nopeasti',
#   'huomio',
#   'ja',
#   'kiinnostus',
#   'isän|maallinen',
#   'brittiläinen',
#   'herras|mies',
#   'keskuudessa',
#   ',',
#   'joka',
#   'haluta',
#   'jäljitellä',
#   'kuuluisa',
#   'sota|sankari'],
#  ['muodikas',
#   'pidetä',
#   'ja',
#   'keikari',
#   'sekä',
#   'muoti|tie|toinen',
#   'suosikki',
#   ',',
#   '(',
#   'mm',
#   'Beau',
#   'Brummell',
#   'käyttää',
#   'tämä',
#   'saapas',
#   ')',
#   ',',
#   'kenkä',
#   'pysyä',
#   'muoti',
#   'aina',
#   '1840|luku',
#   'asti'],
#  ['seuraava',
#   'vuosikymmen',
#   'se',
#   'käyttää',
#   'pitkä',
#   'varrella',
#   'muotoilla',
#   'ja',
#   '1860|luku',
#   'tulla',
#   'se',
#   'syrjäytyä',
#   'nilkkuri',
#   'suosio',
#   'kasvu',
#   'takia',
#   ',',
#   'ratsastus',
#   'luku',
#   'ottaa'],
#  ['ensimmäinen', 'kumi|saapas', 'valmistaa', 'nahas'],
#  ['kuitenkin',
#   'vuosi',
#   '1852',
#   'Hiram',
#   'Hutchinson',
#   'tavata',
#   'Charles',
#   'Goodyearin',
#   'joka',
#   'olla',
#   'juuri',
#   'keksiä',
#   'vulkanointi',
#   'prosessi',
#   'luonnon|kumi'],
#  ['vaikka',
#   'Goodyear',
#   'päättää',
#   'valmistaa',
#   'auton|rengas',
#   ',',
#   'Hutchinson',
#   'ostaa',
#   'patentti',
#   'jalkine',
#   'valmistus',
#   'varten',
#   'ja',
#   'muuttaa',
#   'Ranska',
#   ',',
#   'joka',
#   'perustaa',
#   'vuosi',
#   'vuosi',
#   '1853',
#   '"',
#   'A',
#   "l'",
#   'Aigle',
#   '"',
#   'yritys',
#   '(',
#   '(',
#   '"',
#   'kotka',
#   '"',
#   ',',
#   'joka',
#   'olla',
#   'kunnian|osoitus',
#   'koti|maa',
#   'kohtaan',
#   ')'],
#  ['Hutchinsonin',
#   'perustaa',
#   'yhtiö',
#   'olla',
#   'nykyään',
#   'nimi',
#   'yksinkertainen',
#   '"',
#   'AIGLE',
#   '"',
#   ',',
#   '"',
#   'Kotka',
#   '"',
#   ')'],
#  ['koska',
#   'Ranska',
#   'olla',
#   'perustus|aika',
#   '95',
#   '%',
#   'väestö',
#   'maa|työ',
#   ',',
#   'olla',
#   'kenkä',
#   'joka',
#   'sopia',
#   'työskentely',
#   'pelto',
#   'käyttö',
#   'suku|polvi',
#   'olla',
#   'puu|kenkä',
#   'huomattavasti',
#   'suosittu'],
#  ['kumi|saapas',
#   'ansio',
#   'maa|tilallinen',
#   'ja',
#   'työ',
#   'saattaa',
#   'viimein',
#   'työ|päivä',
#   'jälkeen',
#   'olla',
#   'edelleen',
#   'kuiva',
#   'ja',
#   'puhdas',
#   'jalka',
# ...
#   '2005',
#   'valtio',
#   'nostaa',
#   'palkka',
#   'merkittävästi',
#   ',',
#   'niin',
#   'yksityinen',
#   'kuin',
#   'valtiollinen',
#   'sektori'],
#  ['myös',
#   'eläke',
#   'olla',
#   'nostaa',
#   ',',
#   'ja',
#   'Castro',
#   'luvata',
#   'että',
#   'korotus',
#   'tulla',
#   'myös',
#   'jatkua'],
#  ['Kuuba',
#   'keski|palkka',
#   'arvioida',
#   'olla',
#   'kuitenkin',
#   'hyvä',
#   'muistaa',
#   'se',
#   'että|ei',
#   'se',
#   'vastata',
#   'raha',
#   'todellinen',
#   'ostovoima',
#   'Kuuba'],
#  ['kun',
#   'ottaa',
#   'huomio',
#   'valtio',
#   'subventio',
#   'usea',
#   'perus|tuote',
#   'sekä',
#   'palvelu',
#   'joka',
#   'sosialistinen',
#   'yhteis|kunta',
#   'tarjota',
#   'kansa|lainen',
#   ',',
#   'niin',
#   'voida',
#   'laskea',
#   'että',
#   'keski|verto',
#   'Kuuba',
#   'ansio|tulo',
#   'vastata',
#   'kokonais|arvo',
#   'yli',
#   '800',
#   'euro'],
#  ['viime',
#   'aika',
#   'matkailu',
#   'olla',
#   'tulla',
#   'yhä',
#   'merkittävä',
#   'elin|keino',
#   '(',
#   '44',
#   '%',
#   'valtio',
#   'tulo',
#   'tulla',
#   'matkailu',
#   ')'],
#  ['Kuuba', 'poistua', 'pitää', 'maksaa', '25', 'CUC:n', 'maastapoistumisvero'],
#  ['vuosi',
#   '2005',
#   'Kuuba',
#   'käydä',
#   'yli',
#   '2',
#   ',',
#   '3',
#   'miljoona',
#   'matkailija'],
#  ['suosittu',
#   'matkailija|keskittymä',
#   'olla',
#   'Varadero',
#   'ja',
#   'Guardalavaca',
#   ',',
#   'joka',
#   'käydä',
#   'paljon',
#   'kanadalainen',
#   ',',
#   'meksikolainen',
#   ',',
#   'italialainen',
#   'ja',
#   'saksalainen',
#   ',',
#   'myös',
#   'muutama',
#   'suomalainen|matkan|järjestäjä',
#   'viedä',
#   'matkailija',
#   'Kuuba',
#   'aurinko'],
#  ['Kuuba',
#   'hallitus',
#   'olla',
#   'ilmoittaa',
#   'yhdistää',
#   'tulevaisuus',
#   'vaihtaa',
#   'peso',
#   'ja',
#   'kansallinen',
#   'peso',
#   'yksi',
#   'valuutta'],
#  ['merkittävä',
#   'luonnon|vara',
#   'koboltti',
#   'nikkeli',
#   'rauta|malmi',
#   'kupari',
#   'mangaani',
#   'puu',
#   'merkittävä',
#   'vientituote',
#   'nikkeli',
#   'sokeri',
#   'tupakka',
#   'bio|teknologia',
#   'tuote',
#   'kulttuuri',
#   'musiikki',
#   'Kuuba',
#   'musiikki',
#   'juuri',
#   'olla',
#   'Espanja',
#   'ja',
#   'Länsi-Afrikassa',
#   ',',
#   'mutta',
#   'vaikute',
#   'olla',
#   'tulla',
#   'lukuinen',
#   'muu',
#   'kulttuuri'],
#  ['vastaavasti',
#   'Kuuba',
#   'musiikki',
#   'olla',
#   'vaikuttaa',
#   '1800-',
#   'ja',
#   '1900|luku',
#   'muu',
#   'muassa',
#   'jazz',
#   ',',
#   'salsa',
#   ',',
#   'Argentiina',
#   'tango',
#   'ja',
#   'espanjalainen',
#   'uusi',
#   'flamenco',
#   '(',
#   '"nuevo',
#   'flamenco',
#   '"',
#   ')'],
#  ['viime',
#   'aika',
#   'Kuuba',
#   'musiikki',
#   'olla',
#   'saavuttaa',
#   'kansain|välinen',
#   'suosio',
#   'amerikkalainen',
#   'Ry',
#   'Cooderin',
#   'vuosi',
#   '1997',
#   'tuottaa',
#   'Buena',
#   'Vista',
#   'Social',
#   'Club-levyn',
#   'myötä'],
#  ['Buena',
#   'Vista',
#   'Social',
#   'Clubista',
#   'tehdä',
#   'myös',
#   'laaja|levikkinen',
#   'dokumentti|elokuva'],
#  ['yhtye',
#   'jäsen',
#   'saada',
#   'myös',
#   'henkilö|kohtainen',
#   'julkisuus',
#   'ja',
#   'esimerkiksi',
#   'Ibrahim',
#   'Ferrer',
#   'saavuttaa',
#   'suosio',
#   'myös',
#   'Suomi',
#   'sekä',
#   'esiintyä',
#   'Pori',
#   'jazz',
#   'tapahtuma',
#   'kesä',
#   '2003'],
#  ['urheilu',
#   'jalka|pallo',
#   'ja',
#   'erityisesti',
#   'baseball',
#   'olla',
#   'Kuuba',
#   'suosittu',
#   'urheilu|laji'],
#  ['muu',
#   'suuri',
#   'laji',
#   'olla',
#   'kori|pallo',
#   ',',
#   'lento|pallo',
#   ',',
#   'käsi|pallo',
#   ',',
#   'yleis|urheilu',
#   ',',
#   'paini',
#   'ja',
#   'nyrkkeily'],
#  ['Kuuba',
#   'huippu-urheilu',
#   'olla',
#   'kärsiä',
#   'menestyä',
#   'urheilija',
#   'loikkaus',
#   ',',
#   'esimerkiksi',
#   'usea',
#   'nyrkkeily',
#   'olympia|voittaja',
#   'olla',
#   'loikata',
#   'Saksa'],
#  ['Pelé',
#   ',',
#   'oikea',
#   'nimi',
#   'Edison',
#   'Arantes',
#   'do',
#   'Nascimento',
#   '(',
#   's'],
#  ['23'],
#  ['loka|kuu',
#   '1940',
#   'Três',
#   'Corações',
#   ',',
#   'Minas',
#   'Gerais',
#   ',',
#   'Brasilia',
#   ')',
#   ',',
#   'olla',
#   'Brasilia',
#   'entinen',
#   'jalka|palloilija',
#   ',',
#   'joka',
#   'pidetä',
#   'yksi',
#   'kaikki',
#   'aika',
#   'parhain',
#   'pelaaja'],
#  ['hän', 'olla', 'laji', 'ainoa', 'kolminkertainen', 'maa|ilman|mestari'],
#  ['Pelé',
#   'tehdä',
#   '22|vuotinen',
#   'ura',
#   'aika',
#   'ennätyksellinen',
#   '1',
#   '283',
#   'maali',
#   '1',
#   '363',
#   'ottelu',
#   ',',
#   'joki',
#   'Brasilia',
#   'maa|joukkue',
#   '92',
#   'ottelu',
#   'ja',
#   '77',
#   'maali'],
#  ['hän',
#   'voittaa',
#   'pelata',
#   'sarja',
#   'maali|kuninkuus',
#   'yhteensä',
#   '11',
#   'kerta'],
#  ['32',
#   'erilainen',
#   'joukkue|mestaruus',
#   'Pelé',
#   'jakaa',
#   'jalka|pallo',
#   'voitto',
#   'ykkönen|sija',
#   'Portugali',
#   'Vítor',
#   'Baían',
#   'kanssa'],
#  ['hän',
#   'olla',
#   'erittäin',
#   'monipuolinen',
#   'pelaaja',
#   ',',
#   'molempi|jalkainen',
#   ',',
#   'erittäin',
#   'menestyksekäs',
#   'maalin|tekijä',
#   ',',
#   'mutta',
#   'hallita',
#   'hyvin',
#   'myös',
#   'syöttö',
#   'ja',
#   'harhautus'],
#  ['hän',
#   'olla',
#   'myös',
#   'erinomainen',
#   'puolustaa',
#   'pelaaja',
#   'olla',
#   'hyökkääjä'],
#  ['Peléstä',
#   'olla',
#   'myös',
#   'käyttää',
#   'lempi|nimi',
#   '"',
#   'musta',
#   'timantti',
#   '"'],
#  ['lempi|nimi',
#   'Edison',
#   'Arantes',
#   'do',
#   'Nascimenton',
#   'kertoa',
#   'saada',
#   'hän',
#   'kiusoitella',
#   'luokka|kaveri'],
#  ['varsi|naisesti',
#   'Pelé',
#   'ei',
#   'tarkoittaa',
#   'mikään',
#   ',',
#   'se',
#   'vain',
#   'kuulostaa',
#   'lapsi',
#   'puhe',
#   'portugali'],
#  ['kaikkiaan',
#   'Pelé',
#   'voittaa',
#   'kolme',
#   'maa|ilman|mestaruus',
#   'Brasilia',
#   'maa|joukkue',
#   '1958',
#   ',',
#   '1962',
#   '(',
#   'loukkaantua',
#   'turnaus',
#   'alku',
#   ')',
#   'ja',
#   '1970'],
#  ['hän',
#   'olla',
#   'yksi',
#   'neljä',
#   'pelaaja',
#   ',',
#   'joka',
#   'olla',
#   'tehdä',
#   'maali',
#   'useammassa',
#   'kuin',
#   'yksi',
#   'MM-finaalissa'],
#  ['taustaa',
#   'ja',
#   'lapsuus',
#   'jo',
#   'hän',
#   'isä',
#   'Dondinho',
#   'pelata',
#   'jalka|pallo',
#   'ammatti',
#   ',',
#   'joskaan',
#   'ei',
#   'olla',
#   'koskaan',
#   'huippu|pelaaja',
#   'Brasilia',
#   ':',
#   'ura',
#   'ratkaiseva',
#   'vaihe',
#   'tulla',
#   'polvi|vamma',
#   'olla',
#   'jättää',
#   'hän',
#   'heikosti',
#   'palkata',
#   'keski|taso',
#   'potkija'],
#  ['Pelé',
#   'viettää',
#   'lapsuus',
#   'Três',
#   'Coraçõesin',
#   'ja',
#   'Baurun',
#   'pikku|kaupunki',
#   'köyhälistö|kortteli',
#   'ja',
#   'työskennellä',
#   'seitsen|vuotias',
#   'kengänkillottajana',
#   'ja',
#   'sittemmin',
#   'kenkä|tehdas'],
#  ['jalka|pallo|ura',
#   'Pelé',
#   'aloittaa',
#   'jalka|palloilija',
#   'ura',
#   'seura|taso',
#   '11|vuotias'],
#  ['hän',
#   'olla',
#   '15|vuotias',
#   'Santos',
#   'pyytää',
#   'hän',
#   'joukkue',
#   'vuosi',
#   '1956'],
#  ['hän',
#   'pelata',
#   'ensimmäinen',
#   'kansain|välinen',
#   'ottelu',
#   'vain',
#   'kymmenen',
#   'kuu|kausi',
#   'myöhemmin'],
#  ['Ruotsi',
#   'MM-kisoissa',
#   '1958',
#   'hän',
#   'nousta',
#   'urheilla',
#   'maa|ilma',
#   'tietoisuus',
#   'tehdä',
#   'väli|erä',
#   'Ranska',
#   'vastaan',
#   'hattu|temppu'],
#  ['loppu|ottelu',
#   'Ruotsi',
#   'vastaan',
#   'Pelé',
#   'kuolettaa',
#   'keskitys|pallo',
#   'reisi',
#   ',',
#   'vipata',
#   'se',
#   'yli',
#   'vastustaja',
#   'puolustaja',
#   'ja',
#   'paukauttaa',
#   'pallo',
#   'suoraan',
#   'ilma',
#   'Ruotsi',
#   'verkko',
#   ';',
#   'Brasilia',
#   'siirtyä',
#   '3–1',
#   'johto'],
#  ['hän', 'viimeistellä', 'vielä', 'loppu|numero', '5–2', 'pukata'],
#  ['näin',
#   'hän',
#   'tulla',
#   'kaikki',
#   'aika',
#   'nuori',
#   'maa|ilman|mestaruus',
#   'voittaa',
#   'pelaaja'],
#  ['Pelén',
#   'ura',
#   'synkkä',
#   'muisto',
#   'olla',
#   'jäädä',
#   'Englanti',
#   'MM-turnaus',
#   '1966'],
#  ['sekä',
#   'Bulgaria',
#   'että',
#   'Portugali',
#   'pelaaja',
#   'kolhia',
#   'Brasilia',
#   'tähden',
#   'miltei',
#   'sairaala|kunto',
#   'ja',
#   'kaksi',
#   'edellinen',
#   'maa|ilman|mestaruus',
#   'saavuttaa',
#   'etelä|amerikkalainen|yhdistelmä',
#   'jäädä',
#   'sensaatiomainen',
#   'alku|lohko',
#   'vain',
#   'yksi',
#   'voitto',
#   'saavuttaa'],
#  ['kun',
#   'joukkue',
#   'johto',
#   'sekoilla',
#   'pelaaja|valinta',
#   ',',
#   'Pelé',
#   'ehtiä',
#   'vannoa',
#   'lopettaa',
#   'MM-tasolla'],
#  ['Brasilia',
#   'kannattaja',
#   'onneksi',
#   'hän',
#   'pyörtää',
#   'päätös',
#   'ja',
#   'johtaa',
#   'maa',
#   'kolmas',
#   'maa|ilman|mestaruus',
#   'Meksiko',
#   '1970'],
#  ['Pelé',
#   'pukata',
#   'finaali',
#   'Italia',
#   'vastaan',
#   'avaus|maali',
#   'ja',
#   'pohjustaa',
#   'viimeinen',
#   'maali',
#   'taidokas',
#   'syöttö',
#   '4–1',
#   'päättyä',
#   'ottelu'],
#  ['vuosi',
#   'tämä',
#   'MM-triumfin',
#   'jälkeen',
#   'Pelé',
#   'päättää',
#   'menestyksekäs',
#   'maa|joukkue|ura'],
#  ['Brasilia', 'kohdata', 'Jugoslavia', '18'],
#  ['heinä|kuu',
#   '1971',
#   'Maracanalla',
#   '180',
#   '000',
#   'hurmioitua',
#   'katsoja',
#   'edessä'],
#  ['itse', 'ystävyys|ottelu', 'päättyä', 'tasa', '2', '-', '2'],
#  ['seura|joukkue|jäähyväinen', 'olla', 'edessä', '1'],
#  ['loka|kuu',
#   '1974',
#   ',',
#   'jälleen',
#   'Maracanan',
#   'stadion',
#   ',',
#   'kun',
#   'Santos',
#   'pelata',
#   'Ponte',
#   'Pretaa',
#   'vastaan'],
#  ['sittemmin',
#   'hän',
#   'olla',
#   'kuitenkin',
#   'osittain',
#   'talous|vaikeus',
#   'vuoksi',
#   'låähdettävä',
#   'jatkaa',
#   'ura',
#   'Yhdysvalta',
#   'New',
#   'York',
#   'Cosmosin',
#   'rivi'],
#  ['Maa',
#   'uusi',
#   'ammattilaisliiga',
#   'vahvistaa',
#   'ura',
#   'ehtoo|puoli',
#   'ehtiä',
#   'super|tähti'],
#  ['niinpä',
#   'Pelén',
#   'lopullinen',
#   'peli',
#   'jäähyväiset',
#   'siirtyä',
#   'tapahtua',
#   '1'],
#  ['loka|kuu', '1977'],
#  ['peli|tapa',
#   'Pelén',
#   'pää',
#   'sanoa',
#   'olla',
#   'eräänlainen',
#   'tieto|kone',
#   ',',
#   'joka',
#   'antaa',
#   'jatkuvasti',
#   'uusi',
#   'ohje',
#   'pallo',
#   'ja',
#   'muu',
#   'pelaaja',
#   'sijainti',
#   'muuttua'],
#  ['se',
#   'ansio',
#   'hän',
#   'saattaa',
#   'olla',
#   'oikea',
#   'paikka',
#   'oikea',
#   'aika',
#   'tehdä',
#   'tehokas',
#   'siirto'],
#  ['Pelé',
#   'hallita',
#   'pallo',
#   'eri',
#   'ruumiin|osa',
#   'ja',
#   'yhdistää',
#   'tämä',
#   'erinomainen',
#   'koordinaatio|kyky',
#   'sekä',
#   'tasa|paino',
#   'hallinta'],
#  ['kaikki', 'silata', 'yli|vertainen', 'peli|äly'],
#  ['Pelé',
#   'pelata',
#   'opas',
#   'vastaisesti',
#   'murtautua',
#   'puolustus|sumppu',
#   'läpi',
#   'rangaistus|alue',
#   'keskeltä'],
#  ['hän',
#   'peli|tyyli',
#   'tutkia',
#   'olla',
#   'nimetä',
#   'brasilialaistähden',
#   'vahvuus',
#   'käsi|varsi',
#   'ja',
#   'kyynärpää',
#   'käyttö'],
#  ['tämä',
#   'kyetä',
#   '"',
#   'kauhoa',
#   '"',
#   'vastustaja',
#   'muodostaa',
#   'mies|meri',
#   'keskellä',
#   'niin',
#   ',',
#   'että',
#   'sallittu',
#   'olka|pää|taklaus',
#   'käydä',
#   'miltei',
#   'mahdoton'],
#  ['jalka|tekniikka',
#   'Pelé',
#   'puolestaan',
#   'pystyä',
#   'välttää',
#   'pallon|riisto|yritys'],
#  ['Pelén',
#   'peli|tapa',
#   'olla',
#   'osa',
#   'olo|suhde',
#   'sanella',
#   ',',
#   'sillä',
#   'huippu|aika',
#   '1960|luku',
#   'alku',
#   'laji',
#   'puolustus|taktiikka',
#   'kukoistaa',
#   'ja',
#   'elää',
#   'myös',
#   'jalka|pallo|väki|valta',
#   'kukkea',
#   'aika',
#   ',',
#   'ennen',
#   'kuin',
#   'FIFA',
#   'alkaa',
#   'tiukentaa',
#   'varoitus',
#   'ja',
#   'kentältäpoistokäytäntöä'],
#  ['maineikas',
#   'maali',
#   'yksi',
#   'hän',
#   'legendaarinen',
#   'maali',
#   'syntyä',
#   'Yhdysvalta',
#   'ammattilaisliiga'],
#  ['hän',
#   'potkaista',
#   'pallo',
#   'maali',
#   'puolesta',
#   'kenttä',
#   ',',
#   'mikä',
#   'olla',
#   'mahdollinen',
#   'vastustaja',
#   'maali|vahti',
#   'seikkailun|haluinen|uusi',
#   'takia'],
#  ['urheilu|ura',
#   'jälkeinen',
#   'elämä',
#   'nykyään',
#   'hän',
#   'olla',
#   'UNESCOn',
#   'hyvä',
#   'tahto',
#   'lähettiläs',
#   'ja',
#   'olla',
#   'toimia',
#   'myös',
#   'Brasilia',
#   'urheilu|ministeri'],
#  ['hän',
#   'olla',
#   'myös',
#   'näytellä',
#   'muu',
#   'muassa',
#   'pako',
#   'voitto',
#   'elo|kuva'],
#  ['yksityis|elämä', 'Pelé', 'olla', 'toinen', 'kerta', 'avio'],
#  ['ensimmäinen',
#   'avio|liitto',
#   'hän',
#   'olla',
#   'neljä',
#   'lasta',
#   'ja',
#   'toinen',
#   '1995',
#   'syntyä',
#   'kaksonen'],
#  ['mestaruus',
#   'seura|joukkue',
#   '1956',
#   ',',
#   '1958',
#   ',',
#   '1960',
#   ',',
#   '1961',
#   ',',
#   '1962',
#   ',',
#   '1964',
#   ',',
#   '1965',
#   ',',
#   '1967',
#   ',',
#   '1968',
#   ',',
#   '1969',
#   ',',
#   '1973',
#   'Sao',
#   'Paulon',
#   'osavaltio|mestaruus',
#   '1961',
#   ',',
#   '1962',
#   'Copa',
#   'Libertadores',
#   '1961',
#   ',',
#   '1962',
#   'Club',
#   'World',
#   'Championship',
#   '1961',
#   ',',
#   '1962',
#   ',',
#   '1963',
#   ',',
#   '1964',
#   ',',
#   '1965',
#   ',',
#   '1968',
#   'Brasilia',
#   'cup',
#   '1977',
#   'NASL',
#   '(',
#   'North',
#   'American',
#   'Soccer',
#   'League',
#   ')',
#   'saavutus',
#   'ja',
#   'palkinto',
#   'seura|joukkue',
#   'maa|ilman|cup',
#   '1962',
#   'ja',
#   '1963',
#   'Etelä-Amerikan',
#   'seura|mestaruus',
#   '1962',
#   'ja',
#   '1963',
#   '1999',
#   'vuosi|sata',
#   'paras',
#   'urheilija',
#   'sekä',
#   'Helsinki',
#   'sanoma',
#   ',',
#   'Dagens',
#   'Nyheterin',
#   'että',
#   "L'",
#   'Équipe-lehden',
#   'valita',
#   'kansain|välinen',
#   'olympia|komitea',
#   '1900|luku',
#   'urheilija',
#   'kansain|välinen',
#   'jalka|pallo|liitto',
#   'FIFAn',
#   '"',
#   'vuosi|sata',
#   'pelaaja',
#   '"',
#   'kirjallisuus',
#   'Pele',
#   ':',
#   'jalka|pallo',
#   '-',
#   'elämä',
#   '(',
#   'toimittaa',
#   'Robert',
#   'Fish',
#   ')',
#   'Pelé',
#   '(',
#   'Orlando',
#   'Duarte',
#   ',',
#   'Alex',
#   'Bellos',
#   'ja',
#   'Pele',
#   ',',
#   'ISBN-10',
#   ':',
#   '351-1-20594-3',
#   ')',
#   'Zeitz',
#   'olla',
#   'kaupunki',
#   'Saksa',
#   'Saksi-Anhaltin',
#   'osavaltio',
#   'eteläinen',
#   'osa'],
#  ['se',
#   'sijaita',
#   'Saalen',
#   'sivu|joki',
#   'Weiße',
#   'Elsterin',
#   'laakso',
#   'nelisen|kymmenen',
#   'kilo|metri',
#   'Leipzigista',
#   'etelä'],
#  ['vuosi',
#   '1652',
#   'vuosi',
#   '1718',
#   'Zeitz',
#   'olla',
#   'Sachsen-Zeitzin',
#   'herttua|kunta',
#   'pää|kaupunki'],
#  ['kaupunki',
#   'nähtävyys',
#   'olla',
#   'muu',
#   'muassa',
#   'Schloss',
#   'Moritzburg',
#   '(',
#   '"',
#   'Moritzburgin',
#   'linna',
#   '"',
#   ')',
#   ',',
#   'Deutsche',
#   'Kinderwagenmuseum',
#   '(',
#   '"',
#   'Saksa',
#   'lastenvaunut|museo',
#   '"',
#   ')',
#   'sekä',
#   'tuomio|kirkko',
#   'Zeitzer',
#   'Dom'],
#  ['Zeitzin',
#   'naapuri|kunta',
#   'olla',
#   'Bergisdorf',
#   ',',
#   'Döbris',
#   ',',
#   'Droßdorf',
#   ',',
#   'Elsteraue',
#   ',',
#   'Geußnitz',
#   ',',
#   'Gleina',
#   ',',
#   'Grana',
#   ',',
#   'Nonnewitz',
#   ',',
#   'Theißen',
#   'ja',
#   'Wittgendorf'],
#  ['kausi',
#   '1961–1990',
#   'Zeitzin',
#   'vuotuinen',
#   'keski|lämpö|tila',
#   'olla',
#   '9',
#   ',',
#   '0',
#   '°C'],
#  ['kylmä',
#   'kuu|kausi',
#   'olla',
#   'tammikuu',
#   '(',
#   '-0',
#   ',',
#   '1',
#   '°C',
#   ')',
#   'ja',
#   'lämmin',
#   'heinä|kuu',
#   '(',
#   '18',
#   '°C',
#   ')'],
#  ['keski|määräinen',
#   'vuotuinen',
#   'sade|määrä',
#   'olla',
#   '564',
#   'mm',
#   'sateinen',
#   'kuu|kausi',
#   'olla',
#   'kesä|kuu',
#   'ja',
#   'vähä|sateinen',
#   'vastaavasti',
#   'tammi|helmi|kuu',
#   'sekä',
#   'loka|kuu'],
#  ['historia',
#   'Varhaiskeskiajalla',
#   'nykyinen',
#   'Zeitzin',
#   'seutu',
#   'kuulua',
#   'Thüringenin',
#   'kuningas|kunta'],
#  ['Burgscheidungenin',
#   'liepeillä',
#   'Unstrut-joen',
#   'rantama',
#   'vuosi',
#   '531',
#   'käydä',
#   'taistelu',
#   'frankki|lainen',
#   'merovingit',
#   'voittaa',
#   'thüringeniläiset',
#   ',',
#   'joka',
#   'valta|kunta',
#   'liittää',
#   'frankki',
#   'valta|kunta'],
#  ['Zeitzin', 'alue', 'alkaa', 'muuttaa', 'slaavilainen', 'talon|poika'],
#  ['kuningas',
#   'Henrik',
#   'I',
#   'linnustaja',
#   'rakennuttaa',
#   'nykyinen',
#   'Schloss',
#   'Moritzburgin',
#   'paikka',
#   'linna',
#   'talon|poika',
#   'valvoa'],
#  ['varhainen',
#   'asia|kirja|maininta',
#   'Zeitzista',
#   'olla',
#   'vuosi',
#   '967',
#   'muoto',
#   'Cici'],
#  ['Zeitz',
#   'toimia',
#   'piispa',
#   'asuin|paikka',
#   'vuosi',
#   '968',
#   'vuosi',
#   '1028',
#   ',',
#   'jolloin',
#   'asuin|paikka',
#   'vaihtua',
#   'Naumburg'],
#  ['jälleen', '1200|luku', 'piispa', 'asua', 'Zeitzissa'],
#  ['koko',
#   'hiippa|kunta',
#   'lakkauttaa',
#   '1564',
#   'piispa',
#   'Julius',
#   'von',
#   'Pflugin',
#   'kuolla'],
#  ['barokki|tyylinen',
#   'Schloss',
#   'Moritzburg',
#   'rakentaa',
#   '1600|luku',
#   ',',
#   'ja',
#   'sama',
#   'aika',
#   'kaupunki',
#   'kohota',
#   'usea',
#   'barokki|rakennus'],
#  ['1800|luku',
#   'Zeitziin',
#   'alkaa',
#   'kehittyä',
#   'rusko|hiili',
#   'perustua',
#   'teollisuus'],
#  ['rauta|tie|verkko', 'kaupunki', 'liittää', '1859'],
#  ['teollinen', 'toiminta', 'monipuolistua'],
#  ['kansallis|sosialismi',
#   'kausi',
#   'Zeitzin',
#   'tuntuma',
#   'sijaita',
#   'Rehmdorfiin',
#   'ja',
#   'Gleinaan',
#   'perustaa',
#   'keskitys|leiri',
#   'Wille',
#   ',',
#   'joka',
#   'toimia',
#   'Buchenwaldin',
#   'keskitys|leiri',
#   'alaisuus'],
#  ['suuri',
#   'osa',
#   'Willen',
#   'vanki',
#   'olla',
#   'unkari|juutalainen',
#   ',',
#   'tunnettu',
#   'tulla',
#   'kirjailija',
#   'Imre',
#   'Kertész'],
#  ...]

# %%
phrases = Phrases(sentences, min_count=30, progress_per=10000)

# %%
bigram = Phraser(phrases)

# %% [markdown]
# Transform the corpus based on the bigrams detected:

# %%
sentences = bigram[sentences]

# %% [markdown]
# ## Most Frequent Words:

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 26854

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# [',', 'olla', 'ja', ')', '(', 'hän', ',_joka', 'se', 'vuosi', '"']

# %% [markdown]
# # Training the model

# %%
import multiprocessing

if model_name == 'fasttext':
    from gensim.models import FastText as Model
elif model_name == 'word2vec':
    from gensim.models import word2vec as Model
elif model_name == 'word2vec':
    raise Exception("Non allowed parameter for model.")

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %%
min_count=20
window=2
size=300
sample=6e-5
alpha=0.03
min_alpha=0.0007
negative=20
workers=cores-1

if len(load_model) > 0:
    model = Word2Vec.load(load_model)
else:
    model = Model(min_count=min_count,
                  window=window,
                  size=size,
                  sample=sample,
                  alpha=alpha,
                  min_alpha=min_alpha,
                  negative=negative,
                  workers=workers)

# %% [markdown]
# ## Build vocabulary table:

# %%
t = time()

model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.5 mins

# %% [markdown]
# ## Training:

# %%
t = time()
model.train(sentences, total_examples=model.corpus_count, epochs=30, report_delay=1)
print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 0.27 mins

# %%
model.save(f"{model_name}_{corpus}_{preprocessing_type}_mincount{min_count}_window{window}_size{size}_alpha{alpha}_minalpha{min_alpha}_negative{negative}_workers{workers}.model")
